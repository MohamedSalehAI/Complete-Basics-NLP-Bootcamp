# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
print(nlp.Defaults.stop_words)
# Out:
# {'one', 'yourself', 'but', 'see', 'became', 'could', 'as', 'your', 'various', 'hereafter', 'or', '‘ll', '’m', 'however', 'rather', 'hundred', 'in', 'has', 'have', 'others', 'indeed', 'off', 'to', 'therein', 'least', 'third', 'further', 'while', 'using', 'front', 'both', 'the', 'somewhere', "'re", 'too', 'be', 'if', '‘d', 'here', 'against', 'most', 'no', 'more', 'what', 'therefore', 'any', 'ourselves', 'someone', 'still', 'many', 'their', 'moreover', '’d', 'during', 'might', 'become', 'whom', 'does', 'behind', 'amongst', 'did', 'sixty', 'mine', 'wherein', 'on', 'because', 'whereas', '‘re', 'per', "'m", 'unless', 'regarding', 'go', 'n’t', 'from', 'where', 'whenever', 'i', 'are', 'it', 'fifty', 'them', 'quite', 'beside', 'is', 'often', 'by', '’s', 'sometime', 'anywhere', 'had', 'together', 'do', 'much', 'himself', 'elsewhere', 'back', 'hers', 'only', 'herself', 'something', 'without', 'along', 'then', 'of', 'whole', 'that', 'hence', 'please', 'say', 'almost', 'was', 'below', 'whereby', 'this', 'why', 'besides', 'always', 'thru', 'must', 'name', 'eleven', "'s", 'empty', 'three', 'into', 'nobody', 'us', 'top', 'so', '’ve', 'whose', 'since', 'bottom', 'made', 'several', 'up', 'being', 'its', 'she', 'such', 'anyhow', 'namely', 'few', 'yourselves', 'latter', 'forty', 'who', 'fifteen', 'now', 'thereby', 'used', 'may', 'wherever', 'over', 'eight', 'everything', 'whatever', 'for', 'can', 'perhaps', 'thereafter', 'seem', 'somehow', 'seemed', 'with', 'else', "n't", 'either', 'yet', 'down', 'give', 'n‘t', 'those', 'part', 'were', 'would', '‘ve', 'none', 'his', 'also', 'yours', 'me', 'enough', 'themselves', 'whither', 'again', 'latterly', 'put', 'some', 'keep', 'nevertheless', 'nine', 'although', 'around', 'two', 'alone', 'sometimes', 'six', 'should', 'at', 'beforehand', 'seems', 'thence', 'out', 'thus', 'there', 'will', 'each', 'same', 'among', 'five', 'ten', 'before', 'herein', 'hereby', 'itself', 'toward', '’re', 'towards', 'take', '‘s', 'make', 'ca', 'above', 'everyone', 'every', 'next', 'except', 'he', 'afterwards', 'which', 'once', 'other', 'twelve', 'whereafter', 'formerly', 'about', 'myself', 'until', 'just', 'everywhere', '‘m', 'twenty', 'amount', 'nor', 'when', 'hereupon', 'due', 'we', 'all', 'less', 'they', 'upon', "'ll", 'and', 'nothing', 'ever', 'call', 'though', 'been', 'serious', 're', 'onto', 'under', 'four', 'already', 'thereupon', 'whoever', 'another', 'than', 'anything', 'beyond', 'mostly', 'him', 'done', 'whereupon', 'ours', 'really', 'show', 'well', 'becomes', 'otherwise', 'first', 'move', 'her', 'even', 'our', 'after', 'these', 'doing', 'neither', 'within', "'ve", 'former', 'via', 'full', 'never', 'anyway', 'cannot', 'between', 'very', 'nowhere', 'throughout', 'seeming', 'last', 'anyone', 'side', 'get', 'meanwhile', 'whence', 'a', 'becoming', 'across', 'noone', 'not', 'am', 'how', 'an', 'through', '’ll', 'own', "'d", 'whether', 'my', 'you'}

# %%
nlp.vocab['myself'].is_stop
# Out:
# True

# %%
nlp.vocab['ajhtaj'].is_stop
# Out:
# False

# %%
nlp.vocab['btw'].is_stop
# Out:
# False

# %%
nlp.Defaults.stop_words.add('btw')
nlp.vocab['btw'].is_stop = True

# %%
nlp.vocab['btw'].is_stop
# Out:
# True

# %%
nlp.vocab['beyond'].is_stop
# Out:
# True

# %%
nlp.Defaults.stop_words.remove('beyond')
nlp.vocab['beyond'].is_stop = False

# %%
nlp.vocab['beyond'].is_stop
# Out:
# False

# %%
my_sw = ['i','he','she','it','my','your','his','him','her']

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words('english'))
print(len(stop_words))
stop_words
# Out:
# 198
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
>>> import nltk
>>> nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
example_sent = "This is a sample sentence, And This showing off the stop words filtration."
stop_words = set(stopwords.words('english'))

word_tokens = word_tokenize(example_sent)
word_tokens
# Out:
# ['This',
#  'is',
#  'a',
#  'sample',
#  'sentence',
#  ',',
#  'And',
#  'This',
#  'showing',
#  'off',
#  'the',
#  'stop',
#  'words',
#  'filtration',
#  '.']

# %%
# filtered_sentence = [w for w in word_tokens]

# print(word_tokens)
# print('---------------------------------')
# print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ---------------------------------
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']

# %%
filtered_sentence = [w for w in word_tokens if w not in stop_words]

print(word_tokens)
print('---------------------------------')
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ---------------------------------
# ['This', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'stop', 'words', 'filtration', '.']

# %%
filtered_sentence = [w for w in word_tokens if  w.lower() not in stop_words]

print(word_tokens)
print('---------------------------------')
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'And', 'This', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ---------------------------------
# ['sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
Ar_SW1 = set(stopwords.words("arabic"))
print(len(Ar_SW1))
' | '.join(Ar_SW1)
# Out:
# 701
# 'لولا | رويدك | حيث | مما | عشر | في | ؤ | هَاتِي | ظنَّ | كأنّ | ترك | دينار | جعل | مايو | ذا | هلا | انقلب | مساء | كيفما | لعل | تسع | تبدّل | أنتم | تحت | أنتن | إياهما | نَخْ | بهن | تفعلين | ثمة | بكما | هل | سبعين | حين | درهم | فإن | ستمئة | ياء | هي | غداة | لكي | ذِه | سبحان | تلكما | سبع | إياكما | لهم | ثمانمئة | وإذ | ظ | ذال | بهما | أفعل به | ما برح | كيت | تلقاء | آهِ | إذاً | أنتِ | خ | دال | ى | ساء | الذي | يوليو | عامة | ذ | فلان | أصلا | بطآن | بئس | واو | وَيْ | لستم | لسنا | ر | أيها | أربعمائة | أو | د | أم | أضحى | خبَّر | لكم | جوان | هما | ستة | فاء | مائة | إحدى | إليكَ | تارة | طاء | ضحوة | يمين | تاء | علم | أبريل | ثلاثون | هاهنا | هَذا | إذ | ذلكما | هَذانِ | زود | مكانكم | راح | مرّة | وا | ليسا | بات | ماي | لهن | ثماني | إياها | هاتين | سنتيم | كليهما | أمامك | أقل | بخ | مذ | عسى | فيها | هذين | بضع | حمٌ | عشرة | ك | ألف | ظاء | أربعاء | من | قرش | عما | هذان | إليكم | سبعمئة | هذه | ثمّ | نيسان | مكانكنّ | كرب | أكتوبر | خميس | بَسْ | لا | لاسيما | ز | ش | وإذا | خال | عين | شبه | اللواتي | لام | أمامكَ | يورو | عيانا | أيار | ماذا | ومن | هيت | هاكَ | اخلولق | أجل | غادر | ذواتي | أنشأ | اللاتي | ثلاث | إياك | بل | أيّان | هنا | هيا | آب | بخٍ | زع
# %%
import sys
# !{sys.executable} -m pip install arabic-stopwords

import arabicstopwords.arabicstopwords as stp
# Out:
# Collecting arabic-stopwords
#   Downloading Arabic_Stopwords-0.4.3-py3-none-any.whl.metadata (8.9 kB)
# Collecting pyarabic>=0.6.2 (from arabic-stopwords)
#   Downloading PyArabic-0.6.15-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from pyarabic>=0.6.2->arabic-stopwords) (1.17.0)
# Downloading Arabic_Stopwords-0.4.3-py3-none-any.whl (360 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.5/360.5 kB 2.1 MB/s eta 0:00:00
# Downloading PyArabic-0.6.15-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: pyarabic, arabic-stopwords
# Successfully installed arabic-stopwords-0.4.3 pyarabic-0.6.15

# %%
len(stp.classed_stopwords_list())
# Out:
# 508

# %%
stp.classed_stopwords_list()
# Out:
# dict_keys(['أن', 'إن', 'عل', 'كأن', 'لعل', 'لكن', 'ليت', 'ثنا', 'بيد', 'سوى', 'غير', 'لاسيما', 'أولئك', 'أولئكم', 'أولاء', 'أولالك', 'تان', 'تانك', 'تلك', 'تلكم', 'تلكما', 'ته', 'تي', 'تين', 'تينك', 'ثم', 'ثمة', 'ذا', 'ذاك', 'ذان', 'ذانك', 'ذلك', 'ذلكم', 'ذلكما', 'ذلكن', 'ذه', 'ذوا', 'ذواتا', 'ذواتي', 'ذوو', 'ذوي', 'ذي', 'ذين', 'ذينك', 'كذلك', 'هؤلاء', 'هاتان', 'هاته', 'هاتي', 'هاتين', 'هاهنا', 'هذا', 'هذان', 'هذه', 'هذي', 'هذين', 'هكذا', 'هنا', 'هناك', 'هنالك', 'أي', 'إذ', 'إذا', 'ابن', 'بعض', 'تجاه', 'تلقاء', 'جميع', 'حسب', 'حيث', 'سبحان', 'شبه', 'شطر', 'كل', 'لعمر', 'لما', 'مثل', 'مع', 'معاذ', 'نحو', 'متى', 'أنى', 'أيان', 'أين', 'بكم', 'بما', 'بماذا', 'بمن', 'كم', 'كيف', 'ما', 'ماذا', 'مما', 'ممن', 'من', 'أينما', 'حيثما', 'كيفما', 'مهما', 'أقل', 'أكثر', 'آها', 'بس', 'حاي', 'صه', 'طاق', 'طق', 'عدس', 'كخ', 'نخ', 'هج', 'وا', 'واها', 'وي', 'آمين', 'آه', 'أف', 'أمامك', 'أوه', 'إليك', 'إليكم', 'إليكما', 'إليكن', 'إيه', 'بخ', 'بطآن', 'بله', 'حذار', 'حي', 'دونك', 'رويدك', 'سرعان', 'شتان', 'عليك', 'مكانك', 'مكانكم', 'مكانكما', 'مكانكن', 'مه', 'ها', 'هاؤم', 'هاك', 'هلم', 'هيا', 'هيت', 'هيهات', 'وراءك', 'وشكان', 'ويكأن', 'الألاء', 'الألى', 'التي', 'الذي', 'الذين', 'اللائي', 'اللاتي', 'اللتان', 'اللتيا', 'اللتين', 'اللذان', 'اللذين', 'اللواتي', 'ذات', 'أب', 'أبا', 'أبو', 'أبي', 'أخ', 'أخا', 'أخو', 'أخي', 'حم', 'حما', 'حمو', 'حمي', 'ذو', 'فا', 'فو', 'في', 'لن', 'لو', 'لولا', 'لوما', 'نعم', 'بئس', 'حبذا', 'ساء', 'ساءما', 'نعما', 'لا', 'لات', 'حتى', 'كي', 'أجمع', 'عامة', 'عين', 'كلا', 'كلاهما', 'كلتا', 'كليكما', 'كليهما', 'نفس', 'ء', 'آ', 'أ', 'ؤ', 'ئ', 'ب', 'ة', 'ت', 'ث', 'ج', 'ح', 'خ', 'د', 'ذ', 'ر', 'ز', 'س', 'ش', 'ص', 'ض', 'ط', 'ظ', 'ع', 'غ', 'ف', 'ق', '
 'مابرحتم', 'مابرحتن', 'مابرحا', 'مابرحتا', 'مابرحوا', 'مابرحن', 'مافتئت', 'مافتئنا', 'مافتئتما', 'مافتئتم', 'مافتئتن', 'مافتئا', 'مافتئتا', 'مافتئوا', 'مافتئن', 'ماانفككت', 'ماانفككنا', 'ماانفككتما', 'ماانفككتم', 'ماانفككتن', 'ماانفكت', 'ماانفكا', 'ماانفكتا', 'ماانفكوا', 'ماانفككن'])

# %%
len(stp.stopwords_list())
# Out:
# 13465

# %%
stp.stopwords_list()
# Out:
# ['أن',
#  'أنك',
#  'أنكما',
#  'أنكم',
#  'أنكن',
#  'أننا',
#  'أنها',
#  'أنه',
#  'أنهما',
#  'أنهم',
#  'أنهن',
#  'أني',
#  'بأن',
#  'بأنك',
#  'بأنكما',
#  'بأنكم',
#  'بأنكن',
#  'بأننا',
#  'بأنها',
#  'بأنه',
#  'بأنهما',
#  'بأنهم',
#  'بأنهن',
#  'بأني',
#  'فأن',
#  'فأنك',
#  'فأنكما',
#  'فأنكم',
#  'فأنكن',
#  'فأننا',
#  'فأنها',
#  'فأنه',
#  'فأنهما',
#  'فأنهم',
#  'فأنهن',
#  'فأني',
#  'فبأن',
#  'فبأنك',
#  'فبأنكما',
#  'فبأنكم',
#  'فبأنكن',
#  'فبأننا',
#  'فبأنها',
#  'فبأنه',
#  'فبأنهما',
#  'فبأنهم',
#  'فبأنهن',
#  'فبأني',
#  'فكأن',
#  'فكأنك',
#  'فكأنكما',
#  'فكأنكم',
#  'فكأنكن',
#  'فكأننا',
#  'فكأنها',
#  'فكأنه',
#  'فكأنهما',
#  'فكأنهم',
#  'فكأنهن',
#  'فكأني',
#  'فلأن',
#  'فلأنك',
#  'فلأنكما',
#  'فلأنكم',
#  'فلأنكن',
#  'فلأننا',
#  'فلأنها',
#  'فلأنه',
#  'فلأنهما',
#  'فلأنهم',
#  'فلأنهن',
#  'فلأني',
#  'كأن',
#  'كأنك',
#  'كأنكما',
#  'كأنكم',
#  'كأنكن',
#  'كأننا',
#  'كأنها',
#  'كأنه',
#  'كأنهما',
#  'كأنهم',
#  'كأنهن',
#  'كأني',
#  'لأن',
#  'لأنك',
#  'لأنكما',
#  'لأنكم',
#  'لأنكن',
#  'لأننا',
#  'لأنها',
#  'لأنه',
#  'لأنهما',
#  'لأنهم',
#  'لأنهن',
#  'لأني',
#  'وأن',
#  'وأنك',
#  'وأنكما',
#  'وأنكم',
#  'وأنكن',
#  'وأننا',
#  'وأنها',
#  'وأنه',
#  'وأنهما',
#  'وأنهم',
#  'وأنهن',
#  'وأني',
#  'وبأن',
#  'وبأنك',
#  'وبأنكما',
#  'وبأنكم',
#  'وبأنكن',
#  'وبأننا',
#  'وبأنها',
#  'وبأنه',
#  'وبأنهما',
#  'وبأنهم',
#  'وبأنهن',
#  'وبأني',
#  'وكأن',
#  'وكأنك',
#  'وكأنكما',
#  'وكأنكم',
#  'وكأنكن',
#  'وكأننا',
#  'وكأنها',
#  'وكأنه',
#  'وكأنهما',
#  'وكأنهم',
#  'وكأنهن',
#  'وكأني',
#  'ولأن',
#  'ولأنك',
#  'ولأنكما',
#  'ولأنكم',
#  'ولأنكن',
#  'ولأننا',
#  'ولأنها',
#  'ولأنه',
#  'ولأنهما',
#  'ولأنهم',
#  'ولأنهن',
#  'ولأني',
#  'إن',
#  'إنك',
#  'إنكما',
#  'إنكم',
#  'إنكن',
#  'إننا',
#  'إنها',
#  'إنه',
#  'إنهما',
#  'إنهم',
#  'إنهن',
#  'إني',
#  'أإن',
#  'أإنك',
#  'أإنكما',
#  'أإنكم',
#  'أإنكن',
#  'أإننا',
#  'أإنها',
#  'أإنه',
#  'أإنهما',
#  'أإنهم',
#  'أإنهن',
#  'أإني',
#  'أفإن',
#  'أفإنك',
#  'أفإنكما',
#  'أفإنكم',
#  'أفإنكن',
#  'أفإننا',
#  'أفإنها',
#  'أفإنه',
#  'أفإنهما',
#  'أفإنهم',
#  'أفإنهن',
#  'أفإني',
#  'أفلإن',
#  'أفلإنك',
#  'أفلإنكما',
#  'أفلإنكم',
#  'أفلإنكن',
#  'أفلإننا',
#  'أفلإنها',
#  'أفلإنه',
#  'أفلإنهما',
#  'أفلإنهم',
#  'أفلإنهن',
#  'أفلإني',
#  'ألإن',
#  'ألإنك',
#  'ألإنكما',
#  'ألإنكم',
#  'ألإنكن',
#  'ألإننا',
#  'ألإنها',
#  'ألإنه',
#  'ألإنهما',
#  'ألإنهم',
#  'ألإنهن',
#  'ألإني',
#  'أوإن',
#  'أوإنك',
#  'أوإنكما',
#  'أوإنكم',
#  'أوإنكن',
#  'أوإننا',
#  'أوإنها',
#  'أوإنه',
#  'أوإنهما',
#  'أوإنهم',
#  'أوإنهن',
#  'أوإني',
#  'أولإن',
#  'أولإنك',
#  'أولإنكما',
#  'أولإنكم',
#  'أولإنكن',
#  'أولإننا',
#  'أولإنها',
#  'أولإنه',
#  'أولإنهما',
#  'أولإنهم',
#  'أولإنهن',
#  'أولإني',
#  'فإن',
#  'فإنك',
#  'فإنكما',
#  'فإنكم',
#  'فإنكن',
#  'فإننا',
#  'فإنها',
#  'فإنه',
#  'فإنهما',
#  'فإنهم',
#  'فإنهن',
#  'فإني',
#  'فلإن',
#  'فلإنك',
#  'فلإنكما',
#  'فلإنكم',
#  'فلإنكن',
#  'فلإننا',
#  'فلإنها',
#  'فلإنه',
#  'فلإنهما',
#  'فلإنهم',
#  'فلإنهن',
#  'فلإني',
#  'وإن',
#  'وإنك',
#  'وإنكما',
#  'وإنكم',
#  'وإنكن',
#  'وإننا',
#  'وإنها',
#  'وإنه',
#  'وإنهما',
#  'وإنهم',
#  'وإنهن',
#  'وإني',
#  'ولإن',
#  'ولإنك',
#  'ولإنكما',
#  'ولإنكم',
#  'ولإنكن',
#  'ولإننا',
#  'ولإنها',
#  'ولإنه',
#  'ولإنهما',
#  'ولإنهم',
#  'ولإنهن',
#  'ولإني',
#  'لإن',
#  'لإنك',
#  'لإنكما',
#  'لإنكم',
#  'لإنكن',
#  'لإننا',
#  'لإنها',
#  'لإنه',
#  'لإنهما',
#  'لإنهم',
#  'لإنهن',
#  'لإني',
#  'عل',
#  'فعل',
#  'وعل',
#  'أكأن',
#  'أكأنك',
#  'أكأنكما',
#  'أكأنكم',
#  'أكأنكن',
#  'أكأننا',
#  'أكأنها',
#  'أكأنه',
#  'أكأنهما',
#  'أكأنهم',
#  'أكأنهن',
#  'أكأني',
#  'أفكأن',
#  'أفكأنك',
#  'أفكأنكما',
#  'أفكأنكم',
#  'أفكأنكن',
#  'أفكأننا',
#  'أفكأنها',
#  'أفكأنه',
#  'أفكأنهما',
#  'أفكأنهم',
#  'أفكأنهن',
#  'أفكأني',
#  'أفلكأن',
#  'أفلكأنك',
#  'أفلكأنكما',
#  'أفلكأنكم',
#  'أفلكأنكن',
#  'أفلكأننا',
#  'أفلكأنها',
#  'أفلكأنه',
#  'أفلكأنهما',
#  'أفلكأنهم',
#  'أفلكأنهن',
#  'أفلكأني',
#  'ألكأن',
#  'ألكأنك',
#  'ألكأنكما',
#  'ألكأنكم',
#  'ألكأنكن',
#  'ألكأننا',
#  'ألكأنها',
#  'ألكأنه',
#  'ألكأنهما',
#  'ألكأنهم',
#  'ألكأنهن',
#  'ألكأني',
#  'أوكأن',
#  'أوكأنك',
#  'أوكأنكما',
#  'أوكأنكم',
#  'أوكأنكن',
#  'أوكأننا',
#  'أوكأنها',
#  'أوكأنه',
#  'أوكأنهما',
#  'أوكأنهم',
#  'أوكأنهن',
#  'أوكأني',
#  'أولكأن',
#  'أولكأنك',
#  'أولكأنكما',
#  'أولكأنكم',
#  'أولكأنكن',
#  'أولكأننا',
#  'أولكأنها',
#  'أولكأنه',
#  'أولكأنهما',
#  'أولكأنهم',
#  'أولكأنهن',
#  'أولكأني',
#  'فلكأن',
#  'فلكأنك',
#  'فلكأنكما',
#  'فلكأنكم',
#  'فلكأنكن',
#  'فلكأننا',
#  'فلكأنها',
#  'فلكأنه',
#  'فلكأنهما',
#  'فلكأنهم',
#  'فلكأنهن',
#  'فلكأني',
#  'ولكأن',
#  'ولكأنك',
#  'ولكأنكما',
#  'ولكأنكم',
#  'ولكأنكن',
#  'ولكأننا',
#  'ولكأنها',
#  'ولكأنه',
#  'ولكأنهما',
#  'ولكأنهم',
#  'ولكأنهن',
#  'ولكأني',
#  'لكأن',
#  'لكأنك',
#  'لكأنكما',
#  'لكأنكم',
#  'لكأنكن',
#  'لكأننا',
#  'لكأنها',
#  'لكأنه',
#  'لكأنهما',
#  'لكأنهم',
#  'لكأنهن',
#  'لكأني',
#  'لعل',
#  'لعلك',
#  'لعلكما',
#  'لعلكم',
#  'لعلكن',
#  'لعلنا',
#  'لعلها',
#  'لعله',
#  'لعلهما',
#  'لعلهم',
#  'لعلهن',
#  'لعلي',
#  'ألعل',
#  'ألعلك',
#  'ألعلكما',
#  'ألعلكم',
#  'ألعلكن',
#  'ألعلنا',
#  'ألعلها',
#  'ألعله',
#  'ألعلهما',
#  'ألعلهم',
#  'ألعلهن',
#  'ألعلي',
#  'أفلعل',
#  'أفلعلك',
#  'أفلعلكما',
#  'أفلعلكم',
#  'أفلعلكن',
#  'أفلعلنا',
#  'أفلعلها',
#  'أفلعله',
#  'أفلعلهما',
#  'أفلعلهم',
#  'أفلعلهن',
#  'أفلعلي',
#  'أولعل',
#  'أولعلك',
#  'أولعلكما',
#  'أولعلكم',
#  'أولعلكن',
#  'أولعلنا',
#  'أولعلها',
#  'أولعله',
#  'أولعلهما',
#  'أولعلهم',
#  'أولعلهن',
#  'أولعلي',
#  'فلعل',
#  'فلعلك',
#  'فلعلكما',
#  'فلعلكم',
#  'فلعلكن',
#  'فلعلنا',
#  'فلعلها',
#  'فلعله',
#  'فلعلهما',
#  'فلعلهم',
#  'فلعلهن',
#  'فلعلي',
#  'ولعل',
#  'ولعلك',
#  'ولعلكما',
#  'ولعلكم',
#  'ولعلكن',
#  'ولعلنا',
#  'ولعلها',
#  'ولعله',
#  'ولعلهما',
#  'ولعلهم',
#  'ولعلهن',
#  'ولعلي',
#  'لكن',
#  'لكنك',
#  'لكنكما',
#  'لكنكم',
#  'لكنكن',
#  'لكننا',
#  'لكنها',
#  'لكنه',
#  'لكنهما',
#  'لكنهم',
#  'لكنهن',
#  'لكني',
#  'فلكن',
#  'فلكنك',
#  'فلكنكما',
#  'فلكنكم',
#  'فلكنكن',
#  'فلكننا',
#  'فلكنها',
#  'فلكنه',
#  'فلكنهما',
#  'فلكنهم',
#  'فلكنهن',
#  'فلكني',
#  'ولكن',
#  'ولكنك',
#  'ولكنكما',
#  'ولكنكم',
#  'ولكنكن',
#  'ولكننا',
#  'ولكنها',
#  'ولكنه',
#  'ولكنهما',
#  'ولكنهم',
#  'ولكنهن',
#  'ولكني',
#  'ليت',
#  'ليتك',
#  'ليتكما',
#  'ليتكم',
#  'ليتكن',
#  'ليتنا',
#  'ليتها',
#  'ليته',
#  'ليتهما',
#  'ليتهم',
#  'ليتهن',
#  'ليتي',
#  'فليت',
#  'فليتك',
#  'فليتكما',
#  'فليتكم',
#  'فليتكن',
#  'فليتنا',
#  'فليتها',
#  'فليته',
#  'فليتهما',
#  'فليتهم',
#  'فليتهن',
#  'فليتي',
#  'وليت',
#  'وليتك',
#  'وليتكما',
#  'وليتكم',
#  'وليتكن',
#  'وليتنا',
#  'وليتها',
#  'وليته',
#  'وليتهما',
#  'وليتهم',
#  'وليتهن',
#  'وليتي',
#  'ثنا',
#  'فثنا',
#  'وثنا',
#  'بيد',
#  'فبيد',
#  'وبيد',
#  'سوى',
#  'فسوى',
#  'وسوى',
#  'غير',
#  'غيرك',
#  'غيركما',
#  'غيركم',
#  'غيركن',
#  'غيرنا',
#  'غيرها',
#  'غيره',
#  'غيرهما',
#  'غيرهم',
#  'غيرهن',
#  'غيري',
#  'أكغيره',
#  'أكغيرهما',
#  'أكغيرهم',
#  'أكغيرهن',
#  'أكغير',
#  'أكغيرك',
#  'أكغيركما',
#  'أكغيركم',
#  'أكغيركن',
#  'أكغيرنا',
#  'أكغيرها',
#  'أكغيري',
#  'أغير',
#  'أغيرك',
#  'أغيركما',
#  'أغيركم',
#  'أغيركن',
#  'أغيرنا',
#  'أغيرها',
#  'أغيره',
#  'أغيرهما',
#  'أغيرهم',
#  'أغيرهن',
#  'أغيري',
#  'أبغيره',
#  'أبغيرهما',
#  'أبغيرهم',
#  'أبغيرهن',
#  'أبغير',
#  'أبغيرك',
#  'أبغيركما',
#  'أبغيركم',
#  'أبغيركن',
#  'أبغيرنا',
#  'أبغيرها',
#  'أبغيري',
#  'أفغير',
#  'أفغيرك',
#  'أفغيركما',
#  'أفغيركم',
#  'أفغيركن',
#  'أفغيرنا',
#  'أفغيرها',
#  'أفغيره',
#  'أفغيرهما',
#  'أفغيرهم',
#  'أفغيرهن',
#  'أفغيري',
#  'أفبغيره',
#  'أفبغيرهما',
#  'أفبغيرهم',
#  'أفبغيرهن',
#  'أفبغير',
#  'أفبغيرك',
#  'أفبغيركما',
#  'أفبغيركم',
#  'أفبغيركن',
#  'أفبغيرنا',
#  'أفبغيرها',
#  'أفبغيري',
#  'أفكغيره',
#  'أفكغيرهما',
#  'أفكغيرهم',
#  'أفكغيرهن',
#  'أفكغير',
#  'أفكغيرك',
#  'أفكغيركما',
#  'أفكغيركم',
#  'أفكغيركن',
#  'أفكغيرنا',
#  'أفكغيرها',
#  'أفكغيري',
#  'أفلغير',
#  'أفلغيرك',
#  'أفلغيركما',
#  'أفلغيركم',
#  'أفلغيركن',
#  'أفلغيرنا',
#  'أفلغيرها',
#  'أفلغيره',
#  'أفلغيرهما',
#  'أفلغيرهم',
#  'أفلغيرهن',
#  'أفلغيري',
#  'ألغير',
#  'ألغيرك',
#  'ألغيركما',
#  'ألغيركم',
#  'ألغيركن',
#  'ألغيرنا',
#  'ألغيرها',
#  'ألغيره',
#  'ألغيرهما',
#  'ألغيرهم',
#  'ألغيرهن',
#  'ألغيري',
#  'أوغير',
#  'أوغيرك',
#  'أوغيركما',
#  'أوغيركم',
#  'أوغيركن',
#  'أوغيرنا',
#  'أوغيرها',
#  'أوغيره',
#  'أوغيرهما',
#  'أوغيرهم',
#  'أوغيرهن',
#  'أوغيري',
#  'أوبغيره',
#  'أوبغيرهما',
#  'أوبغيرهم',
#  'أوبغيرهن',
#  'أوبغير',
#  'أوبغيرك',
#  'أوبغيركما',
#  'أوبغيركم',
#  'أوبغيركن',
#  'أوبغيرنا',
#  'أوبغيرها',
#  'أوبغيري',
#  'أوكغيره',
#  'أوكغيرهما',
#  'أوكغيرهم',
#  'أوكغيرهن',
#  'أوكغير',
#  'أوكغيرك',
#  'أوكغيركما',
#  'أوكغيركم',
#  'أوكغيركن',
#  'أوكغيرنا',
#  'أوكغيرها',
#  'أوكغيري',
#  'أولغير',
#  'أولغيرك',
#  'أولغيركما',
#  'أولغيركم',
#  'أولغيركن',
#  'أولغيرنا',
#  'أولغيرها',
#  'أولغيره',
#  'أولغيرهما',
#  'أولغيرهم',
#  'أولغيرهن',
#  'أولغيري',
#  'بغيره',
#  'بغيرهما',
#  'بغيرهم',
#  'بغيرهن',
#  'بغير',
#  'بغيرك',
#  'بغيركما',
#  'بغيركم',
#  'بغيركن',
#  'بغيرنا',
#  'بغيرها',
#  'بغيري',
#  'فغير',
#  'فغيرك',
#  'فغيركما',
#  'فغيركم',
#  'فغيركن',
#  'فغيرنا',
#  'فغيرها',
#  'فغيره',
#  'فغيرهما',
#  'فغيرهم',
#  'فغيرهن',
#  'فغيري',
#  'فبغيره',
#  'فبغيرهما',
#  'فبغيرهم',
#  'فبغيرهن',
#  'فبغير',
#  'فبغيرك',
#  'فبغيركما',
#  'فبغيركم',
#  'فبغيركن',
#  'فبغيرنا',
#  'فبغيرها',
#  'فبغيري',
#  'فكغيره',
#  'فكغيرهما',
#  'فكغيرهم',
#  'فكغيرهن',
#  'فكغير',
#  'فكغيرك',
#  'فكغيركما',
#  'فكغيركم',
#  'فكغيركن',
#  'فكغيرنا',
#  'فكغيرها',
#  'فكغيري',
#  'فلغير',
#  'فلغيرك',
#  'فلغيركما',
#  'فلغيركم',
#  'فلغيركن',
#  'فلغيرنا',
#  'فلغيرها',
#  'فلغيره',
#  'فلغيرهما',
#  'فلغيرهم',
#  'فلغيرهن',
#  'فلغيري',
#  'كغيره',
#  'كغيرهما',
#  'كغيرهم',
#  'كغيرهن',
#  'كغير',
#  'كغيرك',
#  'كغيركما',
#  'كغيركم',
#  'كغيركن',
#  'كغيرنا',
#  'كغيرها',
#  'كغيري',
#  'لغيره',
#  'لغيرهما',
#  'لغيرهم',
#  'لغيرهن',
#  'لغير',
#  'لغيرك',
#  'لغيركما',
#  'لغيركم',
#  'لغيركن',
#  'لغيرنا',
#  'لغيرها',
#  'لغيري',
#  'وغير',
#  'وغيرك',
#  'وغيركما',
#  'وغيركم',
#  'وغيركن',
#  'وغيرنا',
#  'وغيرها',
#  'وغيره',
#  'وغيرهما',
#  'وغيرهم',
#  'وغيرهن',
#  'وغيري',
#  'وبغيره',
#  'وبغيرهما',
#  'وبغيرهم',
#  'وبغيرهن',
#  'وبغير',
#  'وبغيرك',
#  'وبغيركما',
#  'وبغيركم',
#  'وبغيركن',
#  'وبغيرنا',
#  'وبغيرها',
#  'وبغيري',
#  'وكغيره',
#  'وكغيرهما',
#  'وكغيرهم',
#  'وكغيرهن',
#  'وكغير',
#  'وكغيرك',
#  'وكغيركما',
#  'وكغيركم',
#  'وكغيركن',
#  'وكغيرنا',
#  'وكغيرها',
#  'وكغيري',
#  'ولغير',
#  'ولغيرك',
#  'ولغيركما',
#  'ولغيركم',
#  'ولغيركن',
#  'ولغيرنا',
#  'ولغيرها',
#  'ولغيره',
#  'ولغيرهما',
#  'ولغيرهم',
#  'ولغيرهن',
#  'ولغيري',
#  'لاسيما',
#  'فلاسيما',
#  'ولاسيما',
#  'أولئك',
#  'أكأولئك',
#  'أأولئك',
#  'أبأولئك',
#  'أفأولئك',
#  'أفبأولئك',
#  'أفكأولئك',
#  'أفلأولئك',
#  'ألأولئك',
#  'أوأولئك',
#  'أوبأولئك',
#  'أوكأولئك',
#  'أولأولئك',
#  'بأولئك',
#  'فأولئك',
#  'فبأولئك',
#  'فكأولئك',
#  'فلأولئك',
#  'كأولئك',
#  'لأولئك',
#  'وأولئك',
#  'وبأولئك',
#  'وكأولئك',
#  'ولأولئك',
#  'أولئكم',
#  'أكأولئكم',
#  'أأولئكم',
#  'أبأولئكم',
#  'أفأولئكم',
#  'أفبأولئكم',
#  'أفكأولئكم',
#  'أفلأولئكم',
#  'ألأولئكم',
#  'أوأولئكم',
#  'أوبأولئكم',
#  'أوكأولئكم',
#  'أولأولئكم',
#  'بأولئكم',
#  'فأولئكم',
#  'فبأولئكم',
#  'فكأولئكم',
#  'فلأولئكم',
#  'كأولئكم',
#  'لأولئكم',
#  'وأولئكم',
#  'وبأولئكم',
#  'وكأولئكم',
#  'ولأولئكم',
#  'أولاء',
#  'أكأولاء',
#  'أأولاء',
#  'أبأولاء',
#  'أفأولاء',
#  'أفبأولاء',
#  'أفكأولاء',
#  'أفلأولاء',
#  'ألأولاء',
#  'أوأولاء',
#  'أوبأولاء',
#  'أوكأولاء',
#  'أولأولاء',
#  'بأولاء',
#  'فأولاء',
#  'فبأولاء',
#  'فكأولاء',
#  'فلأولاء',
#  'كأولاء',
#  'لأولاء',
#  'وأولاء',
#  'وبأولاء',
#  'وكأولاء',
#  'ولأولاء',
#  'أولالك',
#  'أكأولالك',
#  'أأولالك',
#  'أبأولالك',
#  'أفأولالك',
#  'أفبأولالك',
#  'أفكأولالك',
#  'أفلأولالك',
#  'ألأولالك',
#  'أوأولالك',
#  'أوبأولالك',
#  'أوكأولالك',
#  'أولأولالك',
#  'بأولالك',
#  'فأولالك',
#  'فبأولالك',
#  'فكأولالك',
#  'فلأولالك',
#  'كأولالك',
#  'لأولالك',
#  'وأولالك',
#  'وبأولالك',
#  'وكأولالك',
#  'ولأولالك',
#  'تان',
#  'فتان',
#  'وتان',
#  'تانك',
#  'بتانك',
#  'فتانك',
#  'فبتانك',
#  'فكتانك',
#  'فلتانك',
#  'كتانك',
#  'لتانك',
#  'وتانك',
#  'وبتانك',
#  'وكتانك',
#  'ولتانك',
#  'تلك',
#  'أكتلك',
#  'أتلك',
#  'أبتلك',
#  'أفتلك',
#  'أفبتلك',
#  'أفكتلك',
#  'أفلتلك',
#  'ألتلك',
#  'أوتلك',
#  'أوبتلك',
#  'أوكتلك',
#  'أولتلك',
#  'بتلك',
#  'فتلك',
#  'فبتلك',
#  'فكتلك',
#  'فلتلك',
#  'كتلك',
#  'لتلك',
#  'وتلك',
#  'وبتلك',
#  'وكتلك',
#  'ولتلك',
#  'تلكم',
#  'أكتلكم',
#  'أتلكم',
#  'أبتلكم',
#  'أفتلكم',
#  'أفبتلكم',
#  'أفكتلكم',
#  'أفلتلكم',
#  'ألتلكم',
#  'أوتلكم',
#  'أوبتلكم',
#  'أوكتلكم',
#  'أولتلكم',
#  'بتلكم',
#  'فتلكم',
#  'فبتلكم',
#  'فكتلكم',
#  'فلتلكم',
#  'كتلكم',
#  'لتلكم',
#  'وتلكم',
#  'وبتلكم',
#  ...]

# %%
stp.is_stop(u'ممكن')
# Out:
# False

# %%
stp.is_stop(u'منكم')
# Out:
# True

# %%
stp.stopword_forms(u"على")
# Out:
# ['لعليهن',
#  'وعليهن',
#  'أفلعليكم',
#  'أفلعليكن',
#  'لعليكم',
#  'أفعليكم',
#  'أولعلي',
#  'فلعليهن',
#  'أولعليكم',
#  'فلعلى',
#  'وعلي',
#  'ولعليهما',
#  'فلعليهما',
#  'أعليهما',
#  'أوعلي',
#  'وعليهما',
#  'وعليهم',
#  'ولعلي',
#  'وعليكن',
#  'أفلعليهما',
#  'وعليكما',
#  'عليه',
#  'فعليكما',
#  'فلعليكم',
#  'أعلي',
#  'فلعلي',
#  'ألعليك',
#  'عليكما',
#  'فلعليه',
#  'فعليك',
#  'ألعلي',
#  'وعليه',
#  'لعليها',
#  'فعليهن',
#  'لعليهما',
#  'أفلعليكما',
#  'فعليه',
#  'أعليك',
#  'أفعليه',
#  'وعلى',
#  'أفلعليهم',
#  'فعليكن',
#  'ألعليها',
#  'أولعلى',
#  'أفلعلينا',
#  'ولعلى',
#  'أفلعليك',
#  'أولعليهن',
#  'علينا',
#  'ولعليكم',
#  'أعليكم',
#  'لعليكن',
#  'أفعليهما',
#  'عليكن',
#  'ألعليهن',
#  'فلعليكن',
#  'فعليهما',
#  'ولعليها',
#  'أعليهن',
#  'أعلى',
#  'فعليكم',
#  'فلعليهم',
#  'أفعلى',
#  'عليهن',
#  'أعلينا',
#  'أولعلينا',
#  'أعليهم',
#  'فعلينا',
#  'أوعلى',
#  'أوعليكن',
#  'ألعليكما',
#  'أفعليهن',
#  'ولعليهم',
#  'أفلعليها',
#  'أوعليهن',
#  'فعلي',
#  'ولعليهن',
#  'أفلعلى',
#  'لعليك',
#  'أفعليك',
#  'أولعليكن',
#  'ولعليكما',
#  'أفلعليه',
#  'ولعلينا',
#  'أوعليه',
#  'أفعليهم',
#  'ولعليه',
#  'ألعليكن',
#  'أوعليك',
#  'لعلي',
#  'فعليهم',
#  'ألعليه',
#  'أولعليكما',
#  'أفعليها',
#  'أعليكن',
#  'وعليك',
#  'فعلى',
#  'وعلينا',
#  'فلعليها',
#  'أفعليكما',
#  'أولعليه',
#  'لعليهم',
#  'أوعليها',
#  'عليكم',
#  'على',
#  'أولعليك',
#  'أوعليكما',
#  'لعلينا',
#  'أفعلي',
#  'أولعليهم',
#  'ألعلى',
#  'أفعليكن',
#  'أوعليكم',
#  'لعليكما',
#  'أفعلينا',
#  'عليك',
#  'أولعليهما',
#  'أوعليهم',
#  'أعليه',
#  'ولعليكن',
#  'لعليه',
#  'فلعليك',
#  'فلعلينا',
#  'وعليكم',
#  'عليها',
#  'ألعليهما',
#  'فلعليكما',
#  'أفلعليهن',
#  'أوعليهما',
#  'فعليها',
#  'لعلى',
#  'ولعليك',
#  'أعليها',
#  'عليهم',
#  'أولعليها',
#  'أعليكما',
#  'علي',
#  'أفلعلي',
#  'ألعليهم',
#  'ألعليكم',
#  'أوعلينا',
#  'ألعلينا',
#  'وعليها',
#  'عليهما']

# %%
len(stp.stopword_forms(u"على"))
# Out:
# 144
