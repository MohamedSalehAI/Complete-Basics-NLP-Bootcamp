# %%
from sklearn.metrics import adjusted_rand_score

true_labels = [0, 0, 1, 1]
pred_labels = [1, 1, 0, 0]

score = adjusted_rand_score(true_labels, pred_labels)
print(score)  # 1.0 (perfect clustering, labels can be permuted)
# Out:
# 1.0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %%
documents = ["This little kitty came to play when I was eating at a restaurant.",
             "Merley has the best squooshy kitten belly.",
             "Google Translate app is incredible.",
             "If you open 100 tab in google you get a smiley face.",
             "Best cat photo I've ever taken.",
             "Climbing ninja cat.",
             "Impressed with google map feedback.",
             "Key promoter extension for Google Chrome."]

# %%
# from spacy.lang.en.stop_words import STOP_WORDS

# %%
# vectorizer = TfidfVectorizer(stop_words=list(STOP_WORDS))
# X = vectorizer.fit_transform(documents)

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(documents)

# %%
true_k = 2
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
# Out:
# KMeans(max_iter=100, n_clusters=2, n_init=1)

# %%
set(list(model.labels_))
# Out:
# {np.int32(0), np.int32(1)}

# %%
print("Top terms per cluster:")
# Out:
# Top terms per cluster:

# %%
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
order_centroids
# Out:
# array([[ 5,  3, 21,  7, 32, 23, 30, 16, 28,  2, 20, 26, 27, 24, 25, 31,
#         29, 17, 18, 19, 22, 15, 14, 13, 12,  8,  9, 10, 11,  4,  6,  1,
#          0],
#        [12, 11, 31, 14, 19,  1, 13,  9, 25, 15,  6, 22, 27, 10, 29,  0,
#         24, 17, 26,  8,  4, 18, 32, 28, 30, 16, 23, 21, 20,  5,  7,  2,
#          3]])

# %%
model.cluster_centers_.shape
# Out:
# (2, 33)

# %%
terms = vectorizer.get_feature_names_out()
terms
# Out:
# array(['100', 'app', 'belly', 'best', 'came', 'cat', 'chrome', 'climbing',
#        'eating', 'extension', 'face', 'feedback', 'google', 'impressed',
#        'incredible', 'key', 'kitten', 'kitty', 'little', 'map', 'merley',
#        'ninja', 'open', 'photo', 'play', 'promoter', 'restaurant',
#        'smiley', 'squooshy', 'tab', 'taken', 'translate', 've'],
#       dtype=object)

# %%
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print('------------------------------------------')

print("\n")
print("Prediction")
# Out:
# Cluster 0:
#  cat
#  best
#  ninja
#  climbing
#  ve
#  photo
#  taken
#  kitten
#  squooshy
#  belly
# ------------------------------------------
# Cluster 1:
#  google
#  feedback
#  translate
#  incredible
#  map
#  app
#  impressed
#  extension
#  promoter
#  key
# ------------------------------------------
#
#
# Prediction

# %%
Y = vectorizer.transform(["chrome browser to open."])
prediction = model.predict(Y)
print(prediction)
# Out:
# [1]

# %%
Y = vectorizer.transform(["My cat is hungry."])
prediction = model.predict(Y)
print(prediction)
# Out:
# [0]

# %%
documents = ['ذهبت الي المطعم البارحة',
            'انقطع عني اتصال الانترنت',
             'المطعم يقدم وجبات سيئة',
             'الانترنت اصبح لغة العصر',
             'وجبات المطعم مستواها ردئ' ,
             'اتصال الانترنت لازال منقطع']

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(documents)

# %%
true_k = 2
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
# Out:
# KMeans(max_iter=100, n_clusters=2, n_init=1)

# %%
print("Top terms per cluster:")
# Out:
# Top terms per cluster:

# %%
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
order_centroids
# Out:
# array([[ 2,  0, 11,  7, 15, 12,  1, 13,  4, 17, 16,  9, 10, 14,  8,  6,
#          5,  3],
#        [ 5, 16, 17, 14,  9, 10,  6,  3,  8, 12, 11, 15, 13,  7,  4,  2,
#          1,  0]])

# %%
terms = vectorizer.get_feature_names_out()
terms
# Out:
# array(['اتصال', 'اصبح', 'الانترنت', 'البارحة', 'العصر', 'المطعم', 'الي',
#        'انقطع', 'ذهبت', 'ردئ', 'سيئة', 'عني', 'لازال', 'لغة', 'مستواها',
#        'منقطع', 'وجبات', 'يقدم'], dtype=object)

# %%
for i in range(true_k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
    print('------------------------------------------')

print("\n")
print("Prediction")
# Out:
# Cluster 0:
#  الانترنت
#  اتصال
#  عني
#  انقطع
#  منقطع
#  لازال
#  اصبح
#  لغة
#  العصر
#  يقدم
# ------------------------------------------
# Cluster 1:
#  المطعم
#  وجبات
#  يقدم
#  مستواها
#  ردئ
#  سيئة
#  الي
#  البارحة
#  ذهبت
#  لازال
# ------------------------------------------
#
#
# Prediction

# %%
Y = vectorizer.transform(["وجبات المعطم صارت افضل"])
prediction = model.predict(Y)
print(prediction)
# Out:
# [1]

# %%
Y = vectorizer.transform(["ابن عمي ليس لديه اشتراك في الانترنت"])
prediction = model.predict(Y)
print(prediction)
# Out:
# [0]
