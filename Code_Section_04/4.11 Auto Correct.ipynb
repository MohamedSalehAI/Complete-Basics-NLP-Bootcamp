# %%
# !pip install autocorrect
# Out:
# Collecting autocorrect
#   Downloading autocorrect-2.6.1.tar.gz (622 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.8/622.8 kB 35.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: autocorrect
#   Building wheel for autocorrect (setup.py) ... done
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622364 sha256=1c8a7ff9b696d727de98ebf88a00fec0ee4c778ff6132b7b828d4113c00d83c1
#   Stored in directory: /root/.cache/pip/wheels/b6/28/c2/9ddf8f57f871b55b6fd0ab99c887531fb9a66e5ff236b82aee
# Successfully built autocorrect
# Installing collected packages: autocorrect
# Successfully installed autocorrect-2.6.1

# %%
# !pip install pyspellchecker
# Out:
# Collecting pyspellchecker
#   Downloading pyspellchecker-0.9.0-py3-none-any.whl.metadata (9.3 kB)
# Downloading pyspellchecker-0.9.0-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 106.3 MB/s eta 0:00:00
# Installing collected packages: pyspellchecker
# Successfully installed pyspellchecker-0.9.0

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.12/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.12/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk>=3.9->textblob) (4.67.3)

# %%
from autocorrect import Speller
spell = Speller(lang='en')
spell("I'm not sleapy and tehre is no place I'm giong to.")
# Out:
# "I'm not sleepy and there is no place I'm going to."

# %%
spell("tehre")
# Out:
# 'there'

# %%
spell("I talked to my fatther andd he wasi right")
# Out:
# 'I talked to my father and he was right'

# %%
spell("does this sentece have misspelled wordz?")
# Out:
# 'does this sentence have misspelled word?'

# %%
from spellchecker import SpellChecker

spell = SpellChecker()

# %%
spell.correction("addresz")
# Out:
# 'address'

# %%
spell.correction("besause")
# Out:
# 'because'

# %%
spell.correction("sleapy") , spell.correction("tehre") , spell.correction("giong")
# Out:
# ('sleepy', 'there', 'going')

# %%
words = spell.split_words("this sentnce has mizspelled werds")
[spell.correction(word) for word in words]
# Out:
# ['this', 'sentence', 'has', 'misspelled', 'words']

# %%
spell.unknown(["dilema", "column", "play", "aquire"])
# Out:
# {'aquire', 'dilema'}

# %%
spell.candidates("conceed")
# Out:
# {'concede', 'conceded'}

# %%
spell.candidates("meaj")
# Out:
# {'maj', 'mead', 'meal', 'mean', 'meat'}

# %%
from textblob import Word

word = Word('percieve')

word.spellcheck()
# Out:
# [('perceive', 1.0)]

# %%
word = Word('personell')
word.spellcheck()
# Out:
# [('personal', 0.65),
#  ('personally', 0.2642857142857143),
#  ('peroneal', 0.06428571428571428),
#  ('personnel', 0.014285714285714285),
#  ('personen', 0.007142857142857143)]

# %%
word = Word('meaj')
word.spellcheck()[0][0]
# Out:
# 'mean'
