# %% [markdown]
# ### Imports

# %%
import re
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data

# %%
sentences = """We are about to study the idea of a computational process.
Computational processes are abstract beings that inhabit computers.
As they evolve, processes manipulate other abstract things called data.
The evolution of a process is directed by a pattern of rules
called a program. People create programs to direct processes. In effect,
we conjure the spirits of the computer with our spells."""

# %% [markdown]
# ### Clean Data

# %%
# remove special characters
sentences = re.sub(r'[^A-Za-z0-9]+', ' ', sentences)
sentences
# Out:
# 'We are about to study the idea of a computational process Computational processes are abstract beings that inhabit computers As they evolve processes manipulate other abstract things called data The evolution of a process is directed by a pattern of rules called a program People create programs to direct processes In effect we conjure the spirits of the computer with our spells '

# %%
sentences = " ".join(re.findall(r'[A-Za-z0-9]+',sentences))
sentences
# Out:
# 'We are about to study the idea of a computational process Computational processes are abstract beings that inhabit computers As they evolve processes manipulate other abstract things called data The evolution of a process is directed by a pattern of rules called a program People create programs to direct processes In effect we conjure the spirits of the computer with our spells'

# %%
# remove 1 letter words
sentences = re.sub(r'(?:^| )\w(?:$| )', ' ', sentences).strip()
sentences
# Out:
# 'We are about to study the idea of computational process Computational processes are abstract beings that inhabit computers As they evolve processes manipulate other abstract things called data The evolution of process is directed by pattern of rules called program People create programs to direct processes In effect we conjure the spirits of the computer with our spells'

# %%
# lower all characters
sentences = sentences.lower()
sentences
# Out:
# 'we are about to study the idea of computational process computational processes are abstract beings that inhabit computers as they evolve processes manipulate other abstract things called data the evolution of process is directed by pattern of rules called program people create programs to direct processes in effect we conjure the spirits of the computer with our spells'

# %% [markdown]
# ### Vocabulary

# %%
words = sentences.split()
words
# Out:
# ['we',
#  'are',
#  'about',
#  'to',
#  'study',
#  'the',
#  'idea',
#  'of',
#  'computational',
#  'process',
#  'computational',
#  'processes',
#  'are',
#  'abstract',
#  'beings',
#  'that',
#  'inhabit',
#  'computers',
#  'as',
#  'they',
#  'evolve',
#  'processes',
#  'manipulate',
#  'other',
#  'abstract',
#  'things',
#  'called',
#  'data',
#  'the',
#  'evolution',
#  'of',
#  'process',
#  'is',
#  'directed',
#  'by',
#  'pattern',
#  'of',
#  'rules',
#  'called',
#  'program',
#  'people',
#  'create',
#  'programs',
#  'to',
#  'direct',
#  'processes',
#  'in',
#  'effect',
#  'we',
#  'conjure',
#  'the',
#  'spirits',
#  'of',
#  'the',
#  'computer',
#  'with',
#  'our',
#  'spells']

# %%
vocab = set(words)
vocab
# Out:
# {'about',
#  'abstract',
#  'are',
#  'as',
#  'beings',
#  'by',
#  'called',
#  'computational',
#  'computer',
#  'computers',
#  'conjure',
#  'create',
#  'data',
#  'direct',
#  'directed',
#  'effect',
#  'evolution',
#  'evolve',
#  'idea',
#  'in',
#  'inhabit',
#  'is',
#  'manipulate',
#  'of',
#  'other',
#  'our',
#  'pattern',
#  'people',
#  'process',
#  'processes',
#  'program',
#  'programs',
#  'rules',
#  'spells',
#  'spirits',
#  'study',
#  'that',
#  'the',
#  'they',
#  'things',
#  'to',
#  'we',
#  'with'}

# %%
vocab_size = len(vocab)
embed_dim = 10
context_size = 2

# %% [markdown]
# ### Dictionaries for vocab

# %%
word_to_ix = {word: i for i, word in enumerate(vocab)}
word_to_ix
# Out:
# {'data': 0,
#  'we': 1,
#  'manipulate': 2,
#  'other': 3,
#  'processes': 4,
#  'to': 5,
#  'conjure': 6,
#  'study': 7,
#  'evolve': 8,
#  'our': 9,
#  'idea': 10,
#  'spirits': 11,
#  'of': 12,
#  'directed': 13,
#  'by': 14,
#  'program': 15,
#  'the': 16,
#  'things': 17,
#  'inhabit': 18,
#  'computer': 19,
#  'spells': 20,
#  'beings': 21,
#  'is': 22,
#  'people': 23,
#  'effect': 24,
#  'as': 25,
#  'direct': 26,
#  'about': 27,
#  'they': 28,
#  'in': 29,
#  'programs': 30,
#  'called': 31,
#  'rules': 32,
#  'create': 33,
#  'pattern': 34,
#  'computers': 35,
#  'evolution': 36,
#  'computational': 37,
#  'abstract': 38,
#  'that': 39,
#  'process': 40,
#  'with': 41,
#  'are': 42}

# %%
ix_to_word = {i: word for i, word in enumerate(vocab)}
ix_to_word
# Out:
# {0: 'data',
#  1: 'we',
#  2: 'manipulate',
#  3: 'other',
#  4: 'processes',
#  5: 'to',
#  6: 'conjure',
#  7: 'study',
#  8: 'evolve',
#  9: 'our',
#  10: 'idea',
#  11: 'spirits',
#  12: 'of',
#  13: 'directed',
#  14: 'by',
#  15: 'program',
#  16: 'the',
#  17: 'things',
#  18: 'inhabit',
#  19: 'computer',
#  20: 'spells',
#  21: 'beings',
#  22: 'is',
#  23: 'people',
#  24: 'effect',
#  25: 'as',
#  26: 'direct',
#  27: 'about',
#  28: 'they',
#  29: 'in',
#  30: 'programs',
#  31: 'called',
#  32: 'rules',
#  33: 'create',
#  34: 'pattern',
#  35: 'computers',
#  36: 'evolution',
#  37: 'computational',
#  38: 'abstract',
#  39: 'that',
#  40: 'process',
#  41: 'with',
#  42: 'are'}

# %% [markdown]
# ### Data bags

# %%
# data - [(context), target]


#  """We are about to study the idea of a computational process.
# Computational processes are abstract beings that inhabit computers.
# As they evolve, processes manipulate other abstract things called data.
# The evolution of a process is directed by a pattern of rules
# called a program. People create programs to direct processes. In effect,
# we conjure the spirits of the computer with our spells."""


data = []
for i in range(2, len(words) - 2):
    context = [words[i - 2], words[i - 1], words[i + 1], words[i + 2]]
    target = words[i]
    data.append((context, target))
print(data[:5])
# Out:
# [(['we', 'are', 'to', 'study'], 'about'), (['are', 'about', 'study', 'the'], 'to'), (['about', 'to', 'the', 'idea'], 'study'), (['to', 'study', 'idea', 'of'], 'the'), (['study', 'the', 'of', 'computational'], 'idea')]

# %% [markdown]
# ### Embeddings

# %%
embeddings =  np.random.random_sample((vocab_size, embed_dim))
print(embeddings.shape)
embeddings
# Out:
# (43, 10)
# array([[0.58197648, 0.15863632, 0.19923183, 0.81193023, 0.4056995 ,
#         0.29000617, 0.52129352, 0.36295414, 0.2697724 , 0.5694348 ],
#        [0.56311109, 0.88621543, 0.18417406, 0.88124233, 0.57264852,
#         0.74091261, 0.59780222, 0.94866893, 0.86945424, 0.35355165],
#        [0.2838719 , 0.63671735, 0.94936972, 0.47809097, 0.41043581,
#         0.72842679, 0.22219501, 0.82520227, 0.85140177, 0.52069469],
#        [0.94320979, 0.32338449, 0.97465997, 0.35602651, 0.76397337,
#         0.96009847, 0.32238869, 0.04447779, 0.65651167, 0.17390356]])

# %% [markdown]
# ### Linear Model

# %%
def linear(m, theta):
    w = theta
    return m.dot(w)

# %% [markdown]
# ### Log softmax + NLLloss = Cross Entropy

# %%
def log_softmax(x):
    e_x = np.exp(x - np.max(x))
    return np.log(e_x / e_x.sum())

# %%
def NLLLoss(logs, targets):
    out = logs[range(len(targets)), targets]
    return -out.sum()/len(out)

# %%
def log_softmax_crossentropy_with_logits(logits,target):

    out = np.zeros_like(logits)
    out[np.arange(len(logits)),target] = 1

    softmax = np.exp(logits) / np.exp(logits).sum(axis=-1,keepdims=True)

    return (- out + softmax) / logits.shape[0]

# %% [markdown]
# ### Forward function

# %%
def forward(context_idxs, theta):
    m = embeddings[context_idxs].reshape(1, -1)
    n = linear(m, theta)
    o = log_softmax(n)
    return m, n, o

# %% [markdown]
# ### Backward function

# %%
def backward(preds, theta, target_idxs):
    m, n, o = preds
    dlog = log_softmax_crossentropy_with_logits(n, target_idxs)
    dw = m.T.dot(dlog)
    return dw

# %% [markdown]
# ### Optimize function

# %%
def optimize(theta, grad, lr=0.03):
    theta -= grad * lr
    return theta

# %% [markdown]
# ### Training function

# %%
theta = np.random.uniform(-1, 1, (2 * context_size * embed_dim, vocab_size))

# %%
# [(['we', 'are', 'to', 'study'], 'about'), (['are', 'about', 'study', 'the'], 'to'), (['about', 'to', 'the', 'idea'], 'study'), (['to', 'study', 'idea', 'of'], 'the'), (['study', 'the', 'of', 'computational'], 'idea')]



epoch_losses = {}

for epoch in range(80):

    losses =  []

    for context, target in data:
        context_idxs = np.array([word_to_ix[w] for w in context])
        preds = forward(context_idxs, theta)

        target_idxs = np.array([word_to_ix[target]])
        loss = NLLLoss(preds[-1], target_idxs)

        losses.append(loss)

        grad = backward(preds, theta, target_idxs)
        theta = optimize(theta, grad, lr=0.03)


    epoch_losses[epoch] = losses

# %% [markdown]
# ### Plot loss/epoch

# %%
ix = np.arange(0,80)

fig = plt.figure()
fig.suptitle('Epoch/Losses', fontsize=20)
plt.plot(ix,[epoch_losses[i][0] for i in ix])
plt.xlabel('Epochs', fontsize=12)
plt.ylabel('Losses', fontsize=12)
# Out:
# Text(0, 0.5, 'Losses')

# %% [markdown]
# ### Predict function

# %%
def predict(words):
    context_idxs = np.array([word_to_ix[w] for w in words])
    preds = forward(context_idxs, theta)
    word = ix_to_word[np.argmax(preds[-1])]

    return word

# %%
# (['we', 'are', 'to', 'study'], 'about')
predict(['we', 'are', 'to', 'study'])
# Out:
# 'about'

# %% [markdown]
# ### Accuracy

# %%
def accuracy():
    wrong = 0

    for context, target in data:
        if(predict(context) != target):
            wrong += 1

    return (1 - (wrong / len(data)))

# %%
accuracy()
# Out:
# 1.0
