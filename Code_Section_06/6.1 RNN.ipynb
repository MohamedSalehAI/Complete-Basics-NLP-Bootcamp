# %%
import csv
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, LSTM, Dropout, Activation, Embedding, Bidirectional,SimpleRNN
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
STOPWORDS = set(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
vocab_size = 5000
embedding_dim = 64
max_length = 200
oov_tok = '<OOV>' #  Out of Vocabulary
training_portion = 0.8

# %%
with open("bbc-text.csv", 'r') as csvfile:
  lines=csv.reader(csvfile,delimiter=',')
  for line in lines:
    print("first line ",line)
    break
# Out:
# first line  ['category', 'text']

# %%
articles = []
labels = []

with open("bbc-text.csv", 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    next(reader)
    for row in reader:
        labels.append(row[0])
        article = row[1]
        for word in STOPWORDS:
            token = ' ' + word + ' '
            article = article.replace(token, ' ')
            article = article.replace(' ', ' ')
        articles.append(article)

# %%
len(labels),len(articles)
# Out:
# (909, 909)

# %%
labels[0],articles[0]
# Out:
# ('tech',
#  'tv future hands viewers home theatre systems  plasma high-definition tvs  digital video recorders moving living room  way people watch tv radically different five years  time.  according expert panel gathered annual consumer electronics show las vegas discuss new technologies impact one favourite pastimes. us leading trend  programmes content delivered viewers via home networks  cable  satellite  telecoms companies  broadband service providers front rooms portable devices.  one talked-about technologies ces digital personal video recorders (dvr pvr). set-top boxes  like us tivo uk sky+ system  allow people record  store  play  pause forward wind tv programmes want.  essentially  technology allows much personalised tv. also built-in high-definition tv sets  big business japan us  slower take europe lack high-definition programming. people forward wind adverts  also forget abiding network channel schedules  putting together a-la-carte entertainment. us networks cable satellite companies worried means terms advertising revenues well  brand identity  viewer loyalty channels. although us leads technology moment  also concern raised europe  particularly growing uptake services like sky+.  happens today  see nine months years  time uk   adam hume  bbc broadcast futurologist told bbc news website. likes bbc  issues lost advertising revenue yet. pressing issue moment commercial uk broadcasters  brand loyalty important everyone.  talking content brands rather network brands   said tim hanlon  brand communications firm starcom mediavest.  reality broadband connections  anybody producer content.  added:  challenge hard promote programme much choice.   means  said stacey jolna  senior vice president tv guide tv group  way people find content want watch simplified tv viewers. means networks  us terms  channels could take leaf google book search engine future  instead scheduler help people find want watch. kind channel model might work younger ipod generation used taking control gadgets play them. might suit everyone  panel recognised. older generations comfortable familiar schedules channel brands know getting. perhaps want much choice put hands  mr hanlon suggested.  end  kids diapers pushing buttons already - everything possible available   said mr hanlon.  ultimately  consumer tell market want.   50 000 new gadgets technologies showcased ces  many enhancing tv-watching experience. high-definition tv sets everywhere many new models lcd (liquid crystal display) tvs launched dvr capability built  instead external boxes. one example launched show humax 26-inch lcd tv 80-hour tivo dvr dvd recorder. one us biggest satellite tv companies  directtv  even launched branded dvr show 100-hours recording capability  instant replay  search function. set pause rewind tv 90 hours. microsoft chief bill gates announced pre-show keynote speech partnership tivo  called tivotogo  means people play recorded programmes windows pcs mobile devices. reflect increasing trend freeing multimedia people watch want  want.')

# %%
train_size = int(len(articles) * training_portion)

train_articles = articles[0: train_size]
train_labels = labels[0: train_size]

validation_articles = articles[train_size:]
validation_labels = labels[train_size:]

# %%
print('train_articles' ,len(train_articles))
print('train_labels', len(train_labels))
print('validation_articles', len(validation_articles))
print('validation_labels', len(validation_labels))
# Out:
# train_articles 727
# train_labels 727
# validation_articles 182
# validation_labels 182

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train_articles)
word_index = tokenizer.word_index

# %%
word_index
# Out:
# {'<OOV>': 1,
#  'said': 2,
#  'mr': 3,
#  'would': 4,
#  'year': 5,
#  'also': 6,
#  'new': 7,
#  'us': 8,
#  'people': 9,
#  'one': 10,
#  'could': 11,
#  'last': 12,
#  'first': 13,
#  'time': 14,
#  'two': 15,
#  'world': 16,
#  'government': 17,
#  'years': 18,
#  'uk': 19,
#  'told': 20,
#  'best': 21,
#  'film': 22,
#  'make': 23,
#  'get': 24,
#  'game': 25,
#  'like': 26,
#  'next': 27,
#  'bbc': 28,
#  'back': 29,
#  'music': 30,
#  'made': 31,
#  'many': 32,
#  '000': 33,
#  'three': 34,
#  'number': 35,
#  '1': 36,
#  'market': 37,
#  '2': 38,
#  'labour': 39,
#  'says': 40,
#  'set': 41,
#  'way': 42,
#  'take': 43,
#  'well': 44,
#  '6': 45,
#  'still': 46,
#  'party': 47,
#  'going': 48,
#  'may': 49,
#  'added': 50,
#  'much': 51,
#  'company': 52,
#  'work': 53,
#  'england': 54,
#  'games': 55,
#  'week': 56,
#  'election': 57,
#  'good': 58,
#  'top': 59,
#  'play': 60,
#  'think': 61,
#  'home': 62,
#  'show': 63,
#  'go': 64,
#  '3': 65,
#  'win': 66,
#  'say': 67,
#  'firm': 68,
#  'second': 69,
#  'blair': 70,
#  'technology': 71,
#  'since': 72,
#  'five': 73,
#  'british': 74,
#  '2004': 75,
#  'group': 76,
#  'part': 77,
#  'european': 78,
#  'use': 79,
#  'want': 80,
#  '4': 81,
#  'public': 82,
#  'minister': 83,
#  'news': 84,
#  'country': 85,
#  '10': 86,
#  'see': 87,
#  'even': 88,
#  'million': 89,
#  'final': 90,
#  'growth': 91,
#  'put': 92,
#  'expected': 93,
#  'day': 94,
#  'tv': 95,
#  'end': 96,
#  'economy': 97,
#  'however': 98,
#  'wales': 99,
#  'high': 100,
#  'players': 101,
#  'come': 102,
#  'old': 103,
#  'business': 104,
#  'brown': 105,
#  'four': 106,
#  '5': 107,
#  'months': 108,
#  'service': 109,
#  'long': 110,
#  'half': 111,
#  'already': 112,
#  'london': 113,
#  'net': 114,
#  'six': 115,
#  'life': 116,
#  'deal': 117,
#  'money': 118,
#  'according': 119,
#  'need': 120,
#  'start': 121,
#  '2005': 122,
#  'used': 123,
#  'former': 124,
#  'based': 125,
#  'month': 126,
#  'international': 127,
#  'including': 128,
#  'another': 129,
#  'report': 130,
#  'called': 131,
#  'third': 132,
#  'sales': 133,
#  'digital': 134,
#  'europe': 135,
#  'know': 136,
#  'move': 137,
#  '7': 138,
#  'bank': 139,
#  'services': 140,
#  'plans': 141,
#  'tax': 142,
#  'right': 143,
#  'britain': 144,
#  'director': 145,
#  'really': 146,
#  'china': 147,
#  'chief': 148,
#  'video': 149,
#  'place': 150,
#  'great': 151,
#  'radio': 152,
#  'open': 153,
#  'system': 154,
#  'team': 155,
#  'side': 156,
#  'firms': 157,
#  'record': 158,
#  'player': 159,
#  'help': 160,
#  'general': 161,
#  'companies': 162,
#  'club': 163,
#  'offer': 164,
#  '2003': 165,
#  'rights': 166,
#  'big': 167,
#  'become': 168,
#  'economic': 169,
#  'broadband': 170,
#  'media': 171,
#  'data': 172,
#  'future': 173,
#  'president': 174,
#  'took': 175,
#  'online': 176,
#  'playing': 177,
#  'internet': 178,
#  'ireland': 179,
#  'mobile': 180,
#  'better': 181,
#  'decision': 182,
#  'away': 183,
#  'far': 184,
#  'increase': 185,
#  'real': 186,
#  'howard': 187,
#  'leader': 188,
#  'state': 189,
#  'got': 190,
#  'role': 191,
#  'came': 192,
#  'it': 193,
#  'court': 194,
#  'around': 195,
#  'computer': 196,
#  'scotland': 197,
#  'making': 198,
#  'hit': 199,
#  'times': 200,
#  'able': 201,
#  'up': 202,
#  'software': 203,
#  'without': 204,
#  'campaign': 205,
#  'later': 206,
#  'hard': 207,
#  'award': 208,
#  'every': 209,
#  'cup': 210,
#  'line': 211,
#  'children': 212,
#  'likely': 213,
#  'south': 214,
#  'industry': 215,
#  'spokesman': 216,
#  'left': 217,
#  'users': 218,
#  'give': 219,
#  'law': 220,
#  'office': 221,
#  'foreign': 222,
#  'try': 223,
#  'due': 224,
#  'despite': 225,
#  'star': 226,
#  'little': 227,
#  'pay': 228,
#  'found': 229,
#  'michael': 230,
#  'countries': 231,
#  'whether': 232,
#  'past': 233,
#  'using': 234,
#  'early': 235,
#  'held': 236,
#  'national': 237,
#  'tory': 238,
#  'france': 239,
#  'face': 240,
#  'days': 241,
#  'look': 242,
#  'nations': 243,
#  'cost': 244,
#  'season': 245,
#  'lord': 246,
#  'believe': 247,
#  'financial': 248,
#  'lot': 249,
#  'man': 250,
#  'case': 251,
#  'saying': 252,
#  'sale': 253,
#  'interest': 254,
#  'issue': 255,
#  'john': 256,
#  'cut': 257,
#  'demand': 258,
#  'executive': 259,
#  'oil': 260,
#  'given': 261,
#  'figures': 262,
#  'programme': 263,
#  'january': 264,
#  'full': 265,
#  'lost': 266,
#  'biggest': 267,
#  'problems': 268,
#  'earlier': 269,
#  'prime': 270,
#  'return': 271,
#  'title': 272,
#  'action': 273,
#  'important': 274,
#  'never': 275,
#  'phone': 276,
#  'house': 277,
#  'united': 278,
#  'played': 279,
#  'human': 280,
#  'spending': 281,
#  'following': 282,
#  'run': 283,
#  'network': 284,
#  'although': 285,
#  '20': 286,
#  'films': 287,
#  'injury': 288,
#  'strong': 289,
#  'research': 290,
#  'went': 291,
#  'seen': 292,
#  'local': 293,
#  'share': 294,
#  'find': 295,
#  'control': 296,
#  'ago': 297,
#  'recent': 298,
#  'match': 299,
#  '0': 300,
#  '12': 301,
#  'prices': 302,
#  'analysts': 303,
#  'taking': 304,
#  'awards': 305,
#  'legal': 306,
#  'content': 307,
#  'dvd': 308,
#  'behind': 309,
#  'looking': 310,
#  'something': 311,
#  'coming': 312,
#  'enough': 313,
#  'secretary': 314,
#  'coach': 315,
#  'power': 316,
#  'february': 317,
#  'rise': 318,
#  'personal': 319,
#  'microsoft': 320,
#  'change': 321,
#  'current': 322,
#  'support': 323,
#  'rates': 324,
#  'ever': 325,
#  'production': 326,
#  'chairman': 327,
#  'men': 328,
#  'rate': 329,
#  'meeting': 330,
#  'chancellor': 331,
#  'trade': 332,
#  'budget': 333,
#  'problem': 334,
#  'huge': 335,
#  'things': 336,
#  'job': 337,
#  'david': 338,
#  'sunday': 339,
#  'quarter': 340,
#  'bill': 341,
#  'working': 342,
#  'victory': 343,
#  'thought': 344,
#  'yet': 345,
#  'winning': 346,
#  'less': 347,
#  'always': 348,
#  'series': 349,
#  'point': 350,
#  'information': 351,
#  'book': 352,
#  'might': 353,
#  'getting': 354,
#  'across': 355,
#  '8': 356,
#  'tories': 357,
#  'latest': 358,
#  'e': 359,
#  'access': 360,
#  'free': 361,
#  'india': 362,
#  'friday': 363,
#  'pc': 364,
#  'different': 365,
#  '50': 366,
#  'rugby': 367,
#  'december': 368,
#  'minutes': 369,
#  'keep': 370,
#  'mark': 371,
#  'ahead': 372,
#  'small': 373,
#  'williams': 374,
#  'currently': 375,
#  'shares': 376,
#  'within': 377,
#  'almost': 378,
#  'performance': 379,
#  'actor': 380,
#  'tour': 381,
#  'eu': 382,
#  'family': 383,
#  'continue': 384,
#  'lead': 385,
#  'running': 386,
#  'manager': 387,
#  'today': 388,
#  'chelsea': 389,
#  'major': 390,
#  'hold': 391,
#  'customers': 392,
#  'women': 393,
#  'apple': 394,
#  'consumer': 395,
#  'japan': 396,
#  'conference': 397,
#  'form': 398,
#  'dollar': 399,
#  'known': 400,
#  'policy': 401,
#  'rather': 402,
#  'search': 403,
#  'political': 404,
#  'chance': 405,
#  'tony': 406,
#  'key': 407,
#  'police': 408,
#  'tuesday': 409,
#  'american': 410,
#  '30': 411,
#  'available': 412,
#  'asked': 413,
#  '11': 414,
#  'thing': 415,
#  'act': 416,
#  'jobs': 417,
#  'least': 418,
#  'head': 419,
#  '15': 420,
#  '2001': 421,
#  'term': 422,
#  'investment': 423,
#  'released': 424,
#  'health': 425,
#  'networks': 426,
#  'announced': 427,
#  'weeks': 428,
#  'list': 429,
#  'co': 430,
#  'security': 431,
#  'others': 432,
#  'band': 433,
#  'evidence': 434,
#  'yukos': 435,
#  'union': 436,
#  'beat': 437,
#  'young': 438,
#  'must': 439,
#  'global': 440,
#  'wanted': 441,
#  'live': 442,
#  '9': 443,
#  '40': 444,
#  'anti': 445,
#  'claims': 446,
#  'low': 447,
#  'several': 448,
#  '18': 449,
#  'done': 450,
#  'buy': 451,
#  'album': 452,
#  'lib': 453,
#  'opening': 454,
#  'ms': 455,
#  'web': 456,
#  'means': 457,
#  'costs': 458,
#  'card': 459,
#  'committee': 460,
#  'clear': 461,
#  'agreed': 462,
#  'main': 463,
#  'ministers': 464,
#  'include': 465,
#  'war': 466,
#  'possible': 467,
#  'claim': 468,
#  'league': 469,
#  'level': 470,
#  'members': 471,
#  'statement': 472,
#  'taken': 473,
#  'sony': 474,
#  'sites': 475,
#  'website': 476,
#  'christmas': 477,
#  'plan': 478,
#  'name': 479,
#  'saw': 480,
#  'march': 481,
#  'age': 482,
#  'debt': 483,
#  'cannot': 484,
#  'trial': 485,
#  'liverpool': 486,
#  'hopes': 487,
#  'prize': 488,
#  'australian': 489,
#  'profits': 490,
#  'among': 491,
#  'french': 492,
#  'forward': 493,
#  'out': 494,
#  'involved': 495,
#  'wednesday': 496,
#  'fall': 497,
#  'november': 498,
#  'remain': 499,
#  'feel': 500,
#  'cash': 501,
#  'single': 502,
#  'fans': 503,
#  'success': 504,
#  'mps': 505,
#  'standard': 506,
#  'sold': 507,
#  'car': 508,
#  'mac': 509,
#  'senior': 510,
#  'seven': 511,
#  'hope': 512,
#  'previous': 513,
#  'warned': 514,
#  'gaming': 515,
#  'football': 516,
#  'allow': 517,
#  'hours': 518,
#  'competition': 519,
#  'difficult': 520,
#  'shows': 521,
#  'close': 522,
#  'though': 523,
#  'zealand': 524,
#  'on': 525,
#  'speech': 526,
#  '2002': 527,
#  'recently': 528,
#  'eight': 529,
#  'started': 530,
#  'summer': 531,
#  'to': 532,
#  'mail': 533,
#  'similar': 534,
#  'comes': 535,
#  'liberal': 536,
#  'sir': 537,
#  'result': 538,
#  'release': 539,
#  'york': 540,
#  '17': 541,
#  'largest': 542,
#  'thursday': 543,
#  'test': 544,
#  'fox': 545,
#  'mini': 546,
#  'monday': 547,
#  'city': 548,
#  'saturday': 549,
#  'fourth': 550,
#  'education': 551,
#  'break': 552,
#  '13': 553,
#  'needed': 554,
#  'failed': 555,
#  'showed': 556,
#  'rules': 557,
#  'ban': 558,
#  'russian': 559,
#  'iraq': 560,
#  'annual': 561,
#  'issues': 562,
#  'calls': 563,
#  'wants': 564,
#  'career': 565,
#  'stock': 566,
#  'staff': 567,
#  'spend': 568,
#  'together': 569,
#  'growing': 570,
#  'school': 571,
#  'october': 572,
#  'festival': 573,
#  'olympic': 574,
#  'september': 575,
#  'revealed': 576,
#  'dr': 577,
#  'threat': 578,
#  'large': 579,
#  'black': 580,
#  'scottish': 581,
#  'led': 582,
#  'minimum': 583,
#  'wage': 584,
#  'white': 585,
#  'anything': 586,
#  'parties': 587,
#  'development': 588,
#  'board': 589,
#  'becoming': 590,
#  'quite': 591,
#  'charles': 592,
#  'price': 593,
#  'event': 594,
#  'speed': 595,
#  'per': 596,
#  'leading': 597,
#  'giant': 598,
#  'late': 599,
#  'bid': 600,
#  'centre': 601,
#  'either': 602,
#  'total': 603,
#  'short': 604,
#  'africa': 605,
#  'australia': 606,
#  'version': 607,
#  'value': 608,
#  'higher': 609,
#  'stand': 610,
#  'paid': 611,
#  'order': 612,
#  'paul': 613,
#  'vote': 614,
#  'groups': 615,
#  'gm': 616,
#  'front': 617,
#  'defence': 618,
#  'cards': 619,
#  'believes': 620,
#  'west': 621,
#  'movie': 622,
#  'needs': 623,
#  'force': 624,
#  'let': 625,
#  'care': 626,
#  'that': 627,
#  'goal': 628,
#  'consumers': 629,
#  'sport': 630,
#  'hand': 631,
#  'points': 632,
#  'makes': 633,
#  'reports': 634,
#  'italy': 635,
#  'g': 636,
#  'launched': 637,
#  '100': 638,
#  'v': 639,
#  'university': 640,
#  'speaking': 641,
#  'night': 642,
#  'nothing': 643,
#  'council': 644,
#  '2006': 645,
#  'debut': 646,
#  'conservative': 647,
#  'create': 648,
#  'minute': 649,
#  'charge': 650,
#  'fund': 651,
#  'began': 652,
#  'race': 653,
#  'mean': 654,
#  'television': 655,
#  'commission': 656,
#  '24': 657,
#  'hour': 658,
#  'pre': 659,
#  'stage': 660,
#  'parliament': 661,
#  'happy': 662,
#  '25': 663,
#  'rest': 664,
#  'aid': 665,
#  'site': 666,
#  'investors': 667,
#  'turn': 668,
#  'popular': 669,
#  'fast': 670,
#  'indian': 671,
#  'actress': 672,
#  'attacks': 673,
#  'target': 674,
#  'named': 675,
#  'ball': 676,
#  'gave': 677,
#  'champion': 678,
#  'bring': 679,
#  'in': 680,
#  'entertainment': 681,
#  'comments': 682,
#  'trying': 683,
#  'position': 684,
#  'weekend': 685,
#  'attack': 686,
#  'gordon': 687,
#  'him': 688,
#  'boost': 689,
#  'concerns': 690,
#  'phones': 691,
#  'press': 692,
#  'download': 693,
#  'trust': 694,
#  'turned': 695,
#  'confidence': 696,
#  'grand': 697,
#  'scheme': 698,
#  'drive': 699,
#  'ukip': 700,
#  'google': 701,
#  'instead': 702,
#  'them': 703,
#  'increased': 704,
#  'potential': 705,
#  'jones': 706,
#  'spanish': 707,
#  'germany': 708,
#  'association': 709,
#  'fact': 710,
#  'claimed': 711,
#  'community': 712,
#  'penalty': 713,
#  'stop': 714,
#  'businesses': 715,
#  'moment': 716,
#  'particularly': 717,
#  'experience': 718,
#  'comedy': 719,
#  'immigration': 720,
#  'robinson': 721,
#  'followed': 722,
#  'worked': 723,
#  'mp': 724,
#  'energy': 725,
#  'forced': 726,
#  'lives': 727,
#  'amount': 728,
#  'shown': 729,
#  'special': 730,
#  'takes': 731,
#  'audience': 732,
#  'recovery': 733,
#  'designed': 734,
#  'received': 735,
#  'drugs': 736,
#  'choice': 737,
#  'admitted': 738,
#  '16': 739,
#  'oscar': 740,
#  'project': 741,
#  'proposals': 742,
#  'helped': 743,
#  'street': 744,
#  'matter': 745,
#  'finance': 746,
#  'german': 747,
#  'pressure': 748,
#  'sent': 749,
#  'fell': 750,
#  'brought': 751,
#  'fight': 752,
#  'message': 753,
#  'period': 754,
#  'sound': 755,
#  'laws': 756,
#  'civil': 757,
#  'products': 758,
#  'fiat': 759,
#  'boss': 760,
#  'step': 761,
#  'meet': 762,
#  'box': 763,
#  'bit': 764,
#  'denied': 765,
#  'course': 766,
#  'rising': 767,
#  'reached': 768,
#  'moved': 769,
#  'rule': 770,
#  'became': 771,
#  'couple': 772,
#  'stadium': 773,
#  'whole': 774,
#  'credit': 775,
#  'analyst': 776,
#  'controversial': 777,
#  'battle': 778,
#  'loss': 779,
#  'launch': 780,
#  'numbers': 781,
#  '3g': 782,
#  'wrong': 783,
#  'simply': 784,
#  'talks': 785,
#  'musical': 786,
#  'deficit': 787,
#  'accused': 788,
#  'martin': 789,
#  'poor': 790,
#  'appeal': 791,
#  'bought': 792,
#  'significant': 793,
#  'cases': 794,
#  'decided': 795,
#  'stars': 796,
#  'singer': 797,
#  'magazine': 798,
#  'officials': 799,
#  'exports': 800,
#  'idea': 801,
#  'j': 802,
#  'file': 803,
#  'spam': 804,
#  'technologies': 805,
#  'programmes': 806,
#  'windows': 807,
#  'commons': 808,
#  'policies': 809,
#  'love': 810,
#  'soon': 811,
#  'defeat': 812,
#  'ensure': 813,
#  'trading': 814,
#  'euro': 815,
#  'agreement': 816,
#  'bush': 817,
#  'cuts': 818,
#  'websites': 819,
#  'agency': 820,
#  'call': 821,
#  'off': 822,
#  'areas': 823,
#  'rock': 824,
#  'included': 825,
#  'kennedy': 826,
#  'james': 827,
#  'screen': 828,
#  'challenge': 829,
#  'process': 830,
#  'sure': 831,
#  'opposition': 832,
#  'ask': 833,
#  'june': 834,
#  'member': 835,
#  'story': 836,
#  '2000': 837,
#  'exchange': 838,
#  'politicians': 839,
#  'quality': 840,
#  'management': 841,
#  'selling': 842,
#  'answer': 843,
#  'giving': 844,
#  'lords': 845,
#  'view': 846,
#  'code': 847,
#  'attempt': 848,
#  'english': 849,
#  'authorities': 850,
#  'ray': 851,
#  'official': 852,
#  'range': 853,
#  'so': 854,
#  'response': 855,
#  'machines': 856,
#  'impact': 857,
#  'built': 858,
#  'everything': 859,
#  'meanwhile': 860,
#  'leaders': 861,
#  'whose': 862,
#  'seed': 863,
#  '19': 864,
#  'rose': 865,
#  'average': 866,
#  'agree': 867,
#  'easy': 868,
#  'suspended': 869,
#  'often': 870,
#  'chip': 871,
#  'hoping': 872,
#  'death': 873,
#  'died': 874,
#  'july': 875,
#  'insisted': 876,
#  'talk': 877,
#  '14': 878,
#  'happen': 879,
#  'euros': 880,
#  'offering': 881,
#  'russia': 882,
#  'sell': 883,
#  'champions': 884,
#  'area': 885,
#  'chinese': 886,
#  'song': 887,
#  'thomas': 888,
#  'gerrard': 889,
#  'terms': 890,
#  'everyone': 891,
#  'captain': 892,
#  'premiership': 893,
#  'round': 894,
#  'manchester': 895,
#  'host': 896,
#  'matches': 897,
#  'gone': 898,
#  'peter': 899,
#  'poll': 900,
#  'looked': 901,
#  'kept': 902,
#  'parents': 903,
#  'tough': 904,
#  'spain': 905,
#  'individual': 906,
#  'levels': 907,
#  'markets': 908,
#  'winner': 909,
#  'changes': 910,
#  'private': 911,
#  'forsyth': 912,
#  'longer': 913,
#  'dems': 914,
#  'irish': 915,
#  'bt': 916,
#  'criticised': 917,
#  'build': 918,
#  'manufacturing': 919,
#  'squad': 920,
#  'extra': 921,
#  'peer': 922,
#  'pictures': 923,
#  'files': 924,
#  'cable': 925,
#  'compared': 926,
#  'politics': 927,
#  'common': 928,
#  'expect': 929,
#  'reported': 930,
#  'domestic': 931,
#  'reach': 932,
#  'add': 933,
#  'illegal': 934,
#  'capacity': 935,
#  'created': 936,
#  'offered': 937,
#  'child': 938,
#  'robert': 939,
#  'towards': 940,
#  'social': 941,
#  'drop': 942,
#  'machine': 943,
#  'viewers': 944,
#  'via': 945,
#  'all': 946,
#  'fit': 947,
#  '21': 948,
#  'dropped': 949,
#  'golden': 950,
#  'lower': 951,
#  'output': 952,
#  'opportunity': 953,
#  'felt': 954,
#  'millions': 955,
#  'concerned': 956,
#  'spent': 957,
#  'effort': 958,
#  'history': 959,
#  'banks': 960,
#  'measures': 961,
#  'messages': 962,
#  'bad': 963,
#  'device': 964,
#  'field': 965,
#  'movies': 966,
#  'send': 967,
#  'anyone': 968,
#  'unit': 969,
#  'ceremony': 970,
#  'conservatives': 971,
#  'looks': 972,
#  'straw': 973,
#  'hollywood': 974,
#  'ibm': 975,
#  'air': 976,
#  'athens': 977,
#  'sky': 978,
#  'ipod': 979,
#  'generation': 980,
#  'example': 981,
#  'pcs': 982,
#  'decisions': 983,
#  'cross': 984,
#  'believed': 985,
#  'ready': 986,
#  'north': 987,
#  'chart': 988,
#  'steven': 989,
#  'debate': 990,
#  'schools': 991,
#  'voters': 992,
#  'date': 993,
#  'edinburgh': 994,
#  'previously': 995,
#  'rival': 996,
#  'unlikely': 997,
#  'daily': 998,
#  'newspaper': 999,
#  'central': 1000,
#  ...}

# %%
tokenizer.index_word
# Out:
# {1: '<OOV>',
#  2: 'said',
#  3: 'mr',
#  4: 'would',
#  5: 'year',
#  6: 'also',
#  7: 'new',
#  8: 'us',
#  9: 'people',
#  10: 'one',
#  11: 'could',
#  12: 'last',
#  13: 'first',
#  14: 'time',
#  15: 'two',
#  16: 'world',
#  17: 'government',
#  18: 'years',
#  19: 'uk',
#  20: 'told',
#  21: 'best',
#  22: 'film',
#  23: 'make',
#  24: 'get',
#  25: 'game',
#  26: 'like',
#  27: 'next',
#  28: 'bbc',
#  29: 'back',
#  30: 'music',
#  31: 'made',
#  32: 'many',
#  33: '000',
#  34: 'three',
#  35: 'number',
#  36: '1',
#  37: 'market',
#  38: '2',
#  39: 'labour',
#  40: 'says',
#  41: 'set',
#  42: 'way',
#  43: 'take',
#  44: 'well',
#  45: '6',
#  46: 'still',
#  47: 'party',
#  48: 'going',
#  49: 'may',
#  50: 'added',
#  51: 'much',
#  52: 'company',
#  53: 'work',
#  54: 'england',
#  55: 'games',
#  56: 'week',
#  57: 'election',
#  58: 'good',
#  59: 'top',
#  60: 'play',
#  61: 'think',
#  62: 'home',
#  63: 'show',
#  64: 'go',
#  65: '3',
#  66: 'win',
#  67: 'say',
#  68: 'firm',
#  69: 'second',
#  70: 'blair',
#  71: 'technology',
#  72: 'since',
#  73: 'five',
#  74: 'british',
#  75: '2004',
#  76: 'group',
#  77: 'part',
#  78: 'european',
#  79: 'use',
#  80: 'want',
#  81: '4',
#  82: 'public',
#  83: 'minister',
#  84: 'news',
#  85: 'country',
#  86: '10',
#  87: 'see',
#  88: 'even',
#  89: 'million',
#  90: 'final',
#  91: 'growth',
#  92: 'put',
#  93: 'expected',
#  94: 'day',
#  95: 'tv',
#  96: 'end',
#  97: 'economy',
#  98: 'however',
#  99: 'wales',
#  100: 'high',
#  101: 'players',
#  102: 'come',
#  103: 'old',
#  104: 'business',
#  105: 'brown',
#  106: 'four',
#  107: '5',
#  108: 'months',
#  109: 'service',
#  110: 'long',
#  111: 'half',
#  112: 'already',
#  113: 'london',
#  114: 'net',
#  115: 'six',
#  116: 'life',
#  117: 'deal',
#  118: 'money',
#  119: 'according',
#  120: 'need',
#  121: 'start',
#  122: '2005',
#  123: 'used',
#  124: 'former',
#  125: 'based',
#  126: 'month',
#  127: 'international',
#  128: 'including',
#  129: 'another',
#  130: 'report',
#  131: 'called',
#  132: 'third',
#  133: 'sales',
#  134: 'digital',
#  135: 'europe',
#  136: 'know',
#  137: 'move',
#  138: '7',
#  139: 'bank',
#  140: 'services',
#  141: 'plans',
#  142: 'tax',
#  143: 'right',
#  144: 'britain',
#  145: 'director',
#  146: 'really',
#  147: 'china',
#  148: 'chief',
#  149: 'video',
#  150: 'place',
#  151: 'great',
#  152: 'radio',
#  153: 'open',
#  154: 'system',
#  155: 'team',
#  156: 'side',
#  157: 'firms',
#  158: 'record',
#  159: 'player',
#  160: 'help',
#  161: 'general',
#  162: 'companies',
#  163: 'club',
#  164: 'offer',
#  165: '2003',
#  166: 'rights',
#  167: 'big',
#  168: 'become',
#  169: 'economic',
#  170: 'broadband',
#  171: 'media',
#  172: 'data',
#  173: 'future',
#  174: 'president',
#  175: 'took',
#  176: 'online',
#  177: 'playing',
#  178: 'internet',
#  179: 'ireland',
#  180: 'mobile',
#  181: 'better',
#  182: 'decision',
#  183: 'away',
#  184: 'far',
#  185: 'increase',
#  186: 'real',
#  187: 'howard',
#  188: 'leader',
#  189: 'state',
#  190: 'got',
#  191: 'role',
#  192: 'came',
#  193: 'it',
#  194: 'court',
#  195: 'around',
#  196: 'computer',
#  197: 'scotland',
#  198: 'making',
#  199: 'hit',
#  200: 'times',
#  201: 'able',
#  202: 'up',
#  203: 'software',
#  204: 'without',
#  205: 'campaign',
#  206: 'later',
#  207: 'hard',
#  208: 'award',
#  209: 'every',
#  210: 'cup',
#  211: 'line',
#  212: 'children',
#  213: 'likely',
#  214: 'south',
#  215: 'industry',
#  216: 'spokesman',
#  217: 'left',
#  218: 'users',
#  219: 'give',
#  220: 'law',
#  221: 'office',
#  222: 'foreign',
#  223: 'try',
#  224: 'due',
#  225: 'despite',
#  226: 'star',
#  227: 'little',
#  228: 'pay',
#  229: 'found',
#  230: 'michael',
#  231: 'countries',
#  232: 'whether',
#  233: 'past',
#  234: 'using',
#  235: 'early',
#  236: 'held',
#  237: 'national',
#  238: 'tory',
#  239: 'france',
#  240: 'face',
#  241: 'days',
#  242: 'look',
#  243: 'nations',
#  244: 'cost',
#  245: 'season',
#  246: 'lord',
#  247: 'believe',
#  248: 'financial',
#  249: 'lot',
#  250: 'man',
#  251: 'case',
#  252: 'saying',
#  253: 'sale',
#  254: 'interest',
#  255: 'issue',
#  256: 'john',
#  257: 'cut',
#  258: 'demand',
#  259: 'executive',
#  260: 'oil',
#  261: 'given',
#  262: 'figures',
#  263: 'programme',
#  264: 'january',
#  265: 'full',
#  266: 'lost',
#  267: 'biggest',
#  268: 'problems',
#  269: 'earlier',
#  270: 'prime',
#  271: 'return',
#  272: 'title',
#  273: 'action',
#  274: 'important',
#  275: 'never',
#  276: 'phone',
#  277: 'house',
#  278: 'united',
#  279: 'played',
#  280: 'human',
#  281: 'spending',
#  282: 'following',
#  283: 'run',
#  284: 'network',
#  285: 'although',
#  286: '20',
#  287: 'films',
#  288: 'injury',
#  289: 'strong',
#  290: 'research',
#  291: 'went',
#  292: 'seen',
#  293: 'local',
#  294: 'share',
#  295: 'find',
#  296: 'control',
#  297: 'ago',
#  298: 'recent',
#  299: 'match',
#  300: '0',
#  301: '12',
#  302: 'prices',
#  303: 'analysts',
#  304: 'taking',
#  305: 'awards',
#  306: 'legal',
#  307: 'content',
#  308: 'dvd',
#  309: 'behind',
#  310: 'looking',
#  311: 'something',
#  312: 'coming',
#  313: 'enough',
#  314: 'secretary',
#  315: 'coach',
#  316: 'power',
#  317: 'february',
#  318: 'rise',
#  319: 'personal',
#  320: 'microsoft',
#  321: 'change',
#  322: 'current',
#  323: 'support',
#  324: 'rates',
#  325: 'ever',
#  326: 'production',
#  327: 'chairman',
#  328: 'men',
#  329: 'rate',
#  330: 'meeting',
#  331: 'chancellor',
#  332: 'trade',
#  333: 'budget',
#  334: 'problem',
#  335: 'huge',
#  336: 'things',
#  337: 'job',
#  338: 'david',
#  339: 'sunday',
#  340: 'quarter',
#  341: 'bill',
#  342: 'working',
#  343: 'victory',
#  344: 'thought',
#  345: 'yet',
#  346: 'winning',
#  347: 'less',
#  348: 'always',
#  349: 'series',
#  350: 'point',
#  351: 'information',
#  352: 'book',
#  353: 'might',
#  354: 'getting',
#  355: 'across',
#  356: '8',
#  357: 'tories',
#  358: 'latest',
#  359: 'e',
#  360: 'access',
#  361: 'free',
#  362: 'india',
#  363: 'friday',
#  364: 'pc',
#  365: 'different',
#  366: '50',
#  367: 'rugby',
#  368: 'december',
#  369: 'minutes',
#  370: 'keep',
#  371: 'mark',
#  372: 'ahead',
#  373: 'small',
#  374: 'williams',
#  375: 'currently',
#  376: 'shares',
#  377: 'within',
#  378: 'almost',
#  379: 'performance',
#  380: 'actor',
#  381: 'tour',
#  382: 'eu',
#  383: 'family',
#  384: 'continue',
#  385: 'lead',
#  386: 'running',
#  387: 'manager',
#  388: 'today',
#  389: 'chelsea',
#  390: 'major',
#  391: 'hold',
#  392: 'customers',
#  393: 'women',
#  394: 'apple',
#  395: 'consumer',
#  396: 'japan',
#  397: 'conference',
#  398: 'form',
#  399: 'dollar',
#  400: 'known',
#  401: 'policy',
#  402: 'rather',
#  403: 'search',
#  404: 'political',
#  405: 'chance',
#  406: 'tony',
#  407: 'key',
#  408: 'police',
#  409: 'tuesday',
#  410: 'american',
#  411: '30',
#  412: 'available',
#  413: 'asked',
#  414: '11',
#  415: 'thing',
#  416: 'act',
#  417: 'jobs',
#  418: 'least',
#  419: 'head',
#  420: '15',
#  421: '2001',
#  422: 'term',
#  423: 'investment',
#  424: 'released',
#  425: 'health',
#  426: 'networks',
#  427: 'announced',
#  428: 'weeks',
#  429: 'list',
#  430: 'co',
#  431: 'security',
#  432: 'others',
#  433: 'band',
#  434: 'evidence',
#  435: 'yukos',
#  436: 'union',
#  437: 'beat',
#  438: 'young',
#  439: 'must',
#  440: 'global',
#  441: 'wanted',
#  442: 'live',
#  443: '9',
#  444: '40',
#  445: 'anti',
#  446: 'claims',
#  447: 'low',
#  448: 'several',
#  449: '18',
#  450: 'done',
#  451: 'buy',
#  452: 'album',
#  453: 'lib',
#  454: 'opening',
#  455: 'ms',
#  456: 'web',
#  457: 'means',
#  458: 'costs',
#  459: 'card',
#  460: 'committee',
#  461: 'clear',
#  462: 'agreed',
#  463: 'main',
#  464: 'ministers',
#  465: 'include',
#  466: 'war',
#  467: 'possible',
#  468: 'claim',
#  469: 'league',
#  470: 'level',
#  471: 'members',
#  472: 'statement',
#  473: 'taken',
#  474: 'sony',
#  475: 'sites',
#  476: 'website',
#  477: 'christmas',
#  478: 'plan',
#  479: 'name',
#  480: 'saw',
#  481: 'march',
#  482: 'age',
#  483: 'debt',
#  484: 'cannot',
#  485: 'trial',
#  486: 'liverpool',
#  487: 'hopes',
#  488: 'prize',
#  489: 'australian',
#  490: 'profits',
#  491: 'among',
#  492: 'french',
#  493: 'forward',
#  494: 'out',
#  495: 'involved',
#  496: 'wednesday',
#  497: 'fall',
#  498: 'november',
#  499: 'remain',
#  500: 'feel',
#  501: 'cash',
#  502: 'single',
#  503: 'fans',
#  504: 'success',
#  505: 'mps',
#  506: 'standard',
#  507: 'sold',
#  508: 'car',
#  509: 'mac',
#  510: 'senior',
#  511: 'seven',
#  512: 'hope',
#  513: 'previous',
#  514: 'warned',
#  515: 'gaming',
#  516: 'football',
#  517: 'allow',
#  518: 'hours',
#  519: 'competition',
#  520: 'difficult',
#  521: 'shows',
#  522: 'close',
#  523: 'though',
#  524: 'zealand',
#  525: 'on',
#  526: 'speech',
#  527: '2002',
#  528: 'recently',
#  529: 'eight',
#  530: 'started',
#  531: 'summer',
#  532: 'to',
#  533: 'mail',
#  534: 'similar',
#  535: 'comes',
#  536: 'liberal',
#  537: 'sir',
#  538: 'result',
#  539: 'release',
#  540: 'york',
#  541: '17',
#  542: 'largest',
#  543: 'thursday',
#  544: 'test',
#  545: 'fox',
#  546: 'mini',
#  547: 'monday',
#  548: 'city',
#  549: 'saturday',
#  550: 'fourth',
#  551: 'education',
#  552: 'break',
#  553: '13',
#  554: 'needed',
#  555: 'failed',
#  556: 'showed',
#  557: 'rules',
#  558: 'ban',
#  559: 'russian',
#  560: 'iraq',
#  561: 'annual',
#  562: 'issues',
#  563: 'calls',
#  564: 'wants',
#  565: 'career',
#  566: 'stock',
#  567: 'staff',
#  568: 'spend',
#  569: 'together',
#  570: 'growing',
#  571: 'school',
#  572: 'october',
#  573: 'festival',
#  574: 'olympic',
#  575: 'september',
#  576: 'revealed',
#  577: 'dr',
#  578: 'threat',
#  579: 'large',
#  580: 'black',
#  581: 'scottish',
#  582: 'led',
#  583: 'minimum',
#  584: 'wage',
#  585: 'white',
#  586: 'anything',
#  587: 'parties',
#  588: 'development',
#  589: 'board',
#  590: 'becoming',
#  591: 'quite',
#  592: 'charles',
#  593: 'price',
#  594: 'event',
#  595: 'speed',
#  596: 'per',
#  597: 'leading',
#  598: 'giant',
#  599: 'late',
#  600: 'bid',
#  601: 'centre',
#  602: 'either',
#  603: 'total',
#  604: 'short',
#  605: 'africa',
#  606: 'australia',
#  607: 'version',
#  608: 'value',
#  609: 'higher',
#  610: 'stand',
#  611: 'paid',
#  612: 'order',
#  613: 'paul',
#  614: 'vote',
#  615: 'groups',
#  616: 'gm',
#  617: 'front',
#  618: 'defence',
#  619: 'cards',
#  620: 'believes',
#  621: 'west',
#  622: 'movie',
#  623: 'needs',
#  624: 'force',
#  625: 'let',
#  626: 'care',
#  627: 'that',
#  628: 'goal',
#  629: 'consumers',
#  630: 'sport',
#  631: 'hand',
#  632: 'points',
#  633: 'makes',
#  634: 'reports',
#  635: 'italy',
#  636: 'g',
#  637: 'launched',
#  638: '100',
#  639: 'v',
#  640: 'university',
#  641: 'speaking',
#  642: 'night',
#  643: 'nothing',
#  644: 'council',
#  645: '2006',
#  646: 'debut',
#  647: 'conservative',
#  648: 'create',
#  649: 'minute',
#  650: 'charge',
#  651: 'fund',
#  652: 'began',
#  653: 'race',
#  654: 'mean',
#  655: 'television',
#  656: 'commission',
#  657: '24',
#  658: 'hour',
#  659: 'pre',
#  660: 'stage',
#  661: 'parliament',
#  662: 'happy',
#  663: '25',
#  664: 'rest',
#  665: 'aid',
#  666: 'site',
#  667: 'investors',
#  668: 'turn',
#  669: 'popular',
#  670: 'fast',
#  671: 'indian',
#  672: 'actress',
#  673: 'attacks',
#  674: 'target',
#  675: 'named',
#  676: 'ball',
#  677: 'gave',
#  678: 'champion',
#  679: 'bring',
#  680: 'in',
#  681: 'entertainment',
#  682: 'comments',
#  683: 'trying',
#  684: 'position',
#  685: 'weekend',
#  686: 'attack',
#  687: 'gordon',
#  688: 'him',
#  689: 'boost',
#  690: 'concerns',
#  691: 'phones',
#  692: 'press',
#  693: 'download',
#  694: 'trust',
#  695: 'turned',
#  696: 'confidence',
#  697: 'grand',
#  698: 'scheme',
#  699: 'drive',
#  700: 'ukip',
#  701: 'google',
#  702: 'instead',
#  703: 'them',
#  704: 'increased',
#  705: 'potential',
#  706: 'jones',
#  707: 'spanish',
#  708: 'germany',
#  709: 'association',
#  710: 'fact',
#  711: 'claimed',
#  712: 'community',
#  713: 'penalty',
#  714: 'stop',
#  715: 'businesses',
#  716: 'moment',
#  717: 'particularly',
#  718: 'experience',
#  719: 'comedy',
#  720: 'immigration',
#  721: 'robinson',
#  722: 'followed',
#  723: 'worked',
#  724: 'mp',
#  725: 'energy',
#  726: 'forced',
#  727: 'lives',
#  728: 'amount',
#  729: 'shown',
#  730: 'special',
#  731: 'takes',
#  732: 'audience',
#  733: 'recovery',
#  734: 'designed',
#  735: 'received',
#  736: 'drugs',
#  737: 'choice',
#  738: 'admitted',
#  739: '16',
#  740: 'oscar',
#  741: 'project',
#  742: 'proposals',
#  743: 'helped',
#  744: 'street',
#  745: 'matter',
#  746: 'finance',
#  747: 'german',
#  748: 'pressure',
#  749: 'sent',
#  750: 'fell',
#  751: 'brought',
#  752: 'fight',
#  753: 'message',
#  754: 'period',
#  755: 'sound',
#  756: 'laws',
#  757: 'civil',
#  758: 'products',
#  759: 'fiat',
#  760: 'boss',
#  761: 'step',
#  762: 'meet',
#  763: 'box',
#  764: 'bit',
#  765: 'denied',
#  766: 'course',
#  767: 'rising',
#  768: 'reached',
#  769: 'moved',
#  770: 'rule',
#  771: 'became',
#  772: 'couple',
#  773: 'stadium',
#  774: 'whole',
#  775: 'credit',
#  776: 'analyst',
#  777: 'controversial',
#  778: 'battle',
#  779: 'loss',
#  780: 'launch',
#  781: 'numbers',
#  782: '3g',
#  783: 'wrong',
#  784: 'simply',
#  785: 'talks',
#  786: 'musical',
#  787: 'deficit',
#  788: 'accused',
#  789: 'martin',
#  790: 'poor',
#  791: 'appeal',
#  792: 'bought',
#  793: 'significant',
#  794: 'cases',
#  795: 'decided',
#  796: 'stars',
#  797: 'singer',
#  798: 'magazine',
#  799: 'officials',
#  800: 'exports',
#  801: 'idea',
#  802: 'j',
#  803: 'file',
#  804: 'spam',
#  805: 'technologies',
#  806: 'programmes',
#  807: 'windows',
#  808: 'commons',
#  809: 'policies',
#  810: 'love',
#  811: 'soon',
#  812: 'defeat',
#  813: 'ensure',
#  814: 'trading',
#  815: 'euro',
#  816: 'agreement',
#  817: 'bush',
#  818: 'cuts',
#  819: 'websites',
#  820: 'agency',
#  821: 'call',
#  822: 'off',
#  823: 'areas',
#  824: 'rock',
#  825: 'included',
#  826: 'kennedy',
#  827: 'james',
#  828: 'screen',
#  829: 'challenge',
#  830: 'process',
#  831: 'sure',
#  832: 'opposition',
#  833: 'ask',
#  834: 'june',
#  835: 'member',
#  836: 'story',
#  837: '2000',
#  838: 'exchange',
#  839: 'politicians',
#  840: 'quality',
#  841: 'management',
#  842: 'selling',
#  843: 'answer',
#  844: 'giving',
#  845: 'lords',
#  846: 'view',
#  847: 'code',
#  848: 'attempt',
#  849: 'english',
#  850: 'authorities',
#  851: 'ray',
#  852: 'official',
#  853: 'range',
#  854: 'so',
#  855: 'response',
#  856: 'machines',
#  857: 'impact',
#  858: 'built',
#  859: 'everything',
#  860: 'meanwhile',
#  861: 'leaders',
#  862: 'whose',
#  863: 'seed',
#  864: '19',
#  865: 'rose',
#  866: 'average',
#  867: 'agree',
#  868: 'easy',
#  869: 'suspended',
#  870: 'often',
#  871: 'chip',
#  872: 'hoping',
#  873: 'death',
#  874: 'died',
#  875: 'july',
#  876: 'insisted',
#  877: 'talk',
#  878: '14',
#  879: 'happen',
#  880: 'euros',
#  881: 'offering',
#  882: 'russia',
#  883: 'sell',
#  884: 'champions',
#  885: 'area',
#  886: 'chinese',
#  887: 'song',
#  888: 'thomas',
#  889: 'gerrard',
#  890: 'terms',
#  891: 'everyone',
#  892: 'captain',
#  893: 'premiership',
#  894: 'round',
#  895: 'manchester',
#  896: 'host',
#  897: 'matches',
#  898: 'gone',
#  899: 'peter',
#  900: 'poll',
#  901: 'looked',
#  902: 'kept',
#  903: 'parents',
#  904: 'tough',
#  905: 'spain',
#  906: 'individual',
#  907: 'levels',
#  908: 'markets',
#  909: 'winner',
#  910: 'changes',
#  911: 'private',
#  912: 'forsyth',
#  913: 'longer',
#  914: 'dems',
#  915: 'irish',
#  916: 'bt',
#  917: 'criticised',
#  918: 'build',
#  919: 'manufacturing',
#  920: 'squad',
#  921: 'extra',
#  922: 'peer',
#  923: 'pictures',
#  924: 'files',
#  925: 'cable',
#  926: 'compared',
#  927: 'politics',
#  928: 'common',
#  929: 'expect',
#  930: 'reported',
#  931: 'domestic',
#  932: 'reach',
#  933: 'add',
#  934: 'illegal',
#  935: 'capacity',
#  936: 'created',
#  937: 'offered',
#  938: 'child',
#  939: 'robert',
#  940: 'towards',
#  941: 'social',
#  942: 'drop',
#  943: 'machine',
#  944: 'viewers',
#  945: 'via',
#  946: 'all',
#  947: 'fit',
#  948: '21',
#  949: 'dropped',
#  950: 'golden',
#  951: 'lower',
#  952: 'output',
#  953: 'opportunity',
#  954: 'felt',
#  955: 'millions',
#  956: 'concerned',
#  957: 'spent',
#  958: 'effort',
#  959: 'history',
#  960: 'banks',
#  961: 'measures',
#  962: 'messages',
#  963: 'bad',
#  964: 'device',
#  965: 'field',
#  966: 'movies',
#  967: 'send',
#  968: 'anyone',
#  969: 'unit',
#  970: 'ceremony',
#  971: 'conservatives',
#  972: 'looks',
#  973: 'straw',
#  974: 'hollywood',
#  975: 'ibm',
#  976: 'air',
#  977: 'athens',
#  978: 'sky',
#  979: 'ipod',
#  980: 'generation',
#  981: 'example',
#  982: 'pcs',
#  983: 'decisions',
#  984: 'cross',
#  985: 'believed',
#  986: 'ready',
#  987: 'north',
#  988: 'chart',
#  989: 'steven',
#  990: 'debate',
#  991: 'schools',
#  992: 'voters',
#  993: 'date',
#  994: 'edinburgh',
#  995: 'previously',
#  996: 'rival',
#  997: 'unlikely',
#  998: 'daily',
#  999: 'newspaper',
#  1000: 'central',
#  ...}

# %%
tokenizer.texts_to_sequences(['the cat sat on my table'])
# Out:
# [[1294, 1, 1, 525, 1, 3130]]

# %%
train_sequences = tokenizer.texts_to_sequences(train_articles)
len(train_sequences)
# Out:
# 727

# %%
train_sequences[0]
# Out:
# [95,
#  173,
#  1108,
#  944,
#  62,
#  1190,
#  1228,
#  1,
#  100,
#  1482,
#  1,
#  134,
#  149,
#  4337,
#  1418,
#  1229,
#  1554,
#  42,
#  9,
#  1049,
#  95,
#  1,
#  365,
#  73,
#  18,
#  14,
#  119,
#  3237,
#  1230,
#  3238,
#  561,
#  395,
#  1845,
#  63,
#  4338,
#  4339,
#  1555,
#  7,
#  805,
#  857,
#  10,
#  1231,
#  1,
#  8,
#  597,
#  1846,
#  806,
#  307,
#  1614,
#  944,
#  945,
#  62,
#  426,
#  925,
#  2041,
#  2422,
#  162,
#  170,
#  109,
#  1688,
#  617,
#  1,
#  1419,
#  1014,
#  10,
#  3547,
#  4340,
#  805,
#  3239,
#  134,
#  319,
#  149,
#  4337,
#  4341,
#  3901,
#  41,
#  59,
#  2423,
#  26,
#  8,
#  1,
#  19,
#  978,
#  154,
#  517,
#  9,
#  158,
#  1050,
#  60,
#  4909,
#  493,
#  3548,
#  95,
#  806,
#  80,
#  3902,
#  71,
#  2424,
#  51,
#  1,
#  95,
#  6,
#  858,
#  680,
#  100,
#  1482,
#  95,
#  2288,
#  167,
#  104,
#  396,
#  8,
#  2042,
#  43,
#  135,
#  1109,
#  100,
#  1482,
#  4910,
#  9,
#  493,
#  3548,
#  1,
#  6,
#  2592,
#  1,
#  284,
#  1072,
#  1,
#  1232,
#  569,
#  1775,
#  2593,
#  1,
#  681,
#  8,
#  426,
#  925,
#  2041,
#  162,
#  2159,
#  457,
#  890,
#  1947,
#  1615,
#  44,
#  1847,
#  3240,
#  3549,
#  3241,
#  2781,
#  285,
#  8,
#  2160,
#  71,
#  716,
#  6,
#  1279,
#  1154,
#  135,
#  717,
#  570,
#  1,
#  140,
#  26,
#  978,
#  1616,
#  388,
#  87,
#  1191,
#  108,
#  18,
#  14,
#  19,
#  2043,
#  1,
#  28,
#  1192,
#  1,
#  20,
#  28,
#  84,
#  476,
#  3242,
#  28,
#  562,
#  266,
#  1947,
#  1323,
#  345,
#  1,
#  255,
#  716,
#  1110,
#  19,
#  4342,
#  1847,
#  3241,
#  274,
#  891,
#  1051,
#  307,
#  2161,
#  402,
#  284,
#  2161,
#  2,
#  1556,
#  1,
#  1847,
#  2162,
#  68,
#  1,
#  1,
#  1233,
#  170,
#  1557,
#  2594,
#  1073,
#  307,
#  50,
#  829,
#  207,
#  2289,
#  263,
#  51,
#  737,
#  457,
#  2,
#  1,
#  1,
#  510,
#  1015,
#  174,
#  95,
#  1,
#  95,
#  76,
#  42,
#  9,
#  295,
#  307,
#  80,
#  1049,
#  1,
#  95,
#  944,
#  457,
#  426,
#  8,
#  890,
#  2781,
#  11,
#  43,
#  1,
#  701,
#  352,
#  403,
#  2044,
#  173,
#  702,
#  1,
#  160,
#  9,
#  295,
#  80,
#  1049,
#  1016,
#  1072,
#  1234,
#  353,
#  53,
#  2045,
#  979,
#  980,
#  123,
#  304,
#  296,
#  1617,
#  60,
#  703,
#  353,
#  2425,
#  891,
#  1230,
#  2290,
#  1948,
#  1,
#  4911,
#  4912,
#  1,
#  1072,
#  2161,
#  136,
#  354,
#  1193,
#  80,
#  51,
#  737,
#  92,
#  1108,
#  3,
#  1,
#  1155,
#  96,
#  2782,
#  1,
#  2163,
#  1,
#  112,
#  859,
#  467,
#  412,
#  2,
#  3,
#  1,
#  2595,
#  395,
#  1074,
#  37,
#  80,
#  366,
#  33,
#  7,
#  1617,
#  805,
#  1,
#  3239,
#  32,
#  1,
#  95,
#  1618,
#  718,
#  100,
#  1482,
#  95,
#  2288,
#  1,
#  32,
#  7,
#  1619,
#  1,
#  1,
#  3550,
#  1620,
#  1,
#  637,
#  4341,
#  3243,
#  858,
#  702,
#  1,
#  2423,
#  10,
#  981,
#  637,
#  63,
#  1,
#  1280,
#  1,
#  1,
#  95,
#  1235,
#  658,
#  1,
#  4341,
#  308,
#  3244,
#  10,
#  8,
#  267,
#  2041,
#  95,
#  162,
#  1,
#  88,
#  637,
#  4343,
#  4341,
#  63,
#  638,
#  518,
#  2973,
#  3243,
#  1,
#  1,
#  403,
#  1,
#  41,
#  4909,
#  1,
#  95,
#  1848,
#  518,
#  320,
#  148,
#  341,
#  4344,
#  427,
#  659,
#  63,
#  3903,
#  526,
#  2974,
#  1,
#  131,
#  1,
#  457,
#  9,
#  60,
#  2046,
#  806,
#  807,
#  982,
#  180,
#  1014,
#  4913,
#  1368,
#  1846,
#  1,
#  1949,
#  9,
#  1049,
#  80,
#  80]

# %%
train_padded = pad_sequences(train_sequences, maxlen=max_length,)

# %%
len(train_padded),len(train_padded[0])
# Out:
# (727, 200)

# %%
validation_sequences = tokenizer.texts_to_sequences(validation_articles)
validation_padded = pad_sequences(validation_sequences, maxlen=max_length)

# %%
set(labels)
# Out:
# {'business', 'entertainment', 'politics', 'sport', 'tech'}

# %%
label_tokenizer = Tokenizer()
label_tokenizer.fit_on_texts(labels)

training_label_seq = np.array(label_tokenizer.texts_to_sequences(train_labels))
validation_label_seq = np.array(label_tokenizer.texts_to_sequences(validation_labels))

# %%
label_tokenizer.word_index
# Out:
# {'sport': 1, 'business': 2, 'politics': 3, 'tech': 4, 'entertainment': 5}

# %%
train_labels[0], training_label_seq[0]
# Out:
# ('tech', array([4]))

# %%
model = Sequential()
model.add(Embedding(vocab_size,embedding_dim ))
model.add(Dropout(0.2))
model.add(SimpleRNN(units = embedding_dim))
model.add(Dropout(0.2))
model.add(Dense(6,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001, decay=1e-6)
model.compile(loss='sparse_categorical_crossentropy',optimizer=opt,metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/optimizers/base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
num_epochs = 20
history = model.fit(train_padded, training_label_seq, epochs=num_epochs,
                    validation_data=(validation_padded, validation_label_seq),
                    verbose=2)
# Out:
# Epoch 1/20
# 23/23 - 4s - 189ms/step - accuracy: 0.2050 - loss: 1.7551 - val_accuracy: 0.2747 - val_loss: 1.6994
# Epoch 2/20
# 23/23 - 1s - 61ms/step - accuracy: 0.6080 - loss: 1.4211 - val_accuracy: 0.2802 - val_loss: 1.6702
# Epoch 3/20
# 23/23 - 1s - 62ms/step - accuracy: 0.8817 - loss: 1.0161 - val_accuracy: 0.4066 - val_loss: 1.5956
# Epoch 4/20
# 23/23 - 1s - 62ms/step - accuracy: 0.9739 - loss: 0.5534 - val_accuracy: 0.4121 - val_loss: 1.5164
# Epoch 5/20
# 23/23 - 3s - 110ms/step - accuracy: 0.9972 - loss: 0.2653 - val_accuracy: 0.3681 - val_loss: 1.5143
# Epoch 6/20
# 23/23 - 2s - 108ms/step - accuracy: 1.0000 - loss: 0.1186 - val_accuracy: 0.3791 - val_loss: 1.5702
# Epoch 7/20
# 23/23 - 2s - 90ms/step - accuracy: 1.0000 - loss: 0.0676 - val_accuracy: 0.3626 - val_loss: 1.6075
# Epoch 8/20
# 23/23 - 1s - 60ms/step - accuracy: 1.0000 - loss: 0.0418 - val_accuracy: 0.3736 - val_loss: 1.7188
# Epoch 9/20
# 23/23 - 3s - 111ms/step - accuracy: 1.0000 - loss: 0.0314 - val_accuracy: 0.3407 - val_loss: 1.8035
# Epoch 10/20
# 23/23 - 1s - 61ms/step - accuracy: 1.0000 - loss: 0.0241 - val_accuracy: 0.3462 - val_loss: 1.7193
# Epoch 11/20
# 23/23 - 1s - 62ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 0.3407 - val_loss: 1.7783
# Epoch 12/20
# 23/23 - 1s - 61ms/step - accuracy: 1.0000 - loss: 0.0148 - val_accuracy: 0.3571 - val_loss: 1.7583
# Epoch 13/20
# 23/23 - 2s - 76ms/step - accuracy: 1.0000 - loss: 0.0132 - val_accuracy: 0.3516 - val_loss: 1.8512
# Epoch 14/20
# 23/23 - 3s - 124ms/step - accuracy: 1.0000 - loss: 0.0114 - val_accuracy: 0.3736 - val_loss: 1.7720
# Epoch 15/20
# 23/23 - 3s - 109ms/step - accuracy: 1.0000 - loss: 0.0101 - val_accuracy: 0.3462 - val_loss: 1.8539
# Epoch 16/20
# 23/23 - 4s - 158ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.3462 - val_loss: 1.8604
# Epoch 17/20
# 23/23 - 4s - 160ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.3626 - val_loss: 1.8502
# Epoch 18/20
# 23/23 - 4s - 181ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.3571 - val_loss: 1.8810
# Epoch 19/20
# 23/23 - 1s - 63ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.3516 - val_loss: 1.9137
# Epoch 20/20
# 23/23 - 1s - 61ms/step - accuracy: 1.0000 - loss: 0.0059 - val_accuracy: 0.3462 - val_loss: 1.8959

# %%
loss,acc=model.evaluate(validation_padded,validation_label_seq)
print("accuracy",acc)
print("loss",loss)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.3462 - loss: 1.8959
# accuracy 0.3461538553237915
# loss 1.8959136009216309

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
txt = ["blair prepares to name poll date tony blair is likely to name 5 may as election day when parliament returns from its easter break  the bbc s political editor has learned.  andrew marr says mr blair will ask the queen on 4 or 5 april to dissolve parliament at the end of that week. mr blair has so far resisted calls for him to name the day but all parties have stepped up campaigning recently. downing street would not be drawn on the claim  saying election timing was a matter for the prime minister.  a number 10 spokeswoman would only say:  he will announce an election when he wants to announce an election.  the move will signal a frantic week at westminster as the government is likely to try to get key legislation through parliament. the government needs its finance bill  covering the budget plans  to be passed before the commons closes for business at the end of the session on 7 april.  but it will also seek to push through its serious and organised crime bill and id cards bill. mr marr said on wednesday s today programme:  there s almost nobody at a senior level inside the government or in parliament itself who doesn t expect the election to be called on 4 or 5 april.  as soon as the commons is back after the short easter recess  tony blair whips up to the palace  asks the queen to dissolve parliament ... and we re going.  the labour government officially has until june 2006 to hold general election  but in recent years governments have favoured four-year terms."]

seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)

labels=['sport', 'business', 'politics', 'tech', 'entertainment']

print(pred)
print(np.argmax(pred))
print(labels[np.argmax(pred)-1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# [[0.03099893 0.21535465 0.00159236 0.2661869  0.44854704 0.03732016]]
# 4
# tech

# %%
txt = ["call to save manufacturing jobs the trades union congress (tuc) is calling on the government to stem job losses in manufacturing firms by reviewing the help it gives companies.  the tuc said in its submission before the budget that action is needed because of 105 000 jobs lost from the sector over the last year. it calls for better pensions  child care provision and decent wages. the 36-page submission also urges the government to examine support other european countries provide to industry. tuc general secretary brendan barber called for  a commitment to policies that will make a real difference to the lives of working people.    greater investment in childcare strategies and the people delivering that childcare will increases the options available to working parents   he said.  a commitment to our public services and manufacturing sector ensures that we can continue to compete on a global level and deliver the frontline services that this country needs.  he also called for  practical measures  to help pensioners  especially women who he said  are most likely to retire in poverty . the submission also calls for decent wages and training for people working in the manufacturing sector."]

seq = tokenizer.texts_to_sequences(txt)
padded = pad_sequences(seq, maxlen=max_length)
pred = model.predict(padded)
labels=['sport', 'business', 'politics', 'tech', 'entertainment']


print(pred)
print(np.argmax(pred))
print(labels[np.argmax(pred)-1])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# [[0.06169169 0.0101242  0.7505688  0.03949035 0.08354854 0.05457645]]
# 2
# business
