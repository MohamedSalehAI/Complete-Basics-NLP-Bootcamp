# %%
# !pip install -U deep_translator
# Out:
# Collecting deep_translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.12/dist-packages (from deep_translator) (4.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from deep_translator) (2.32.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep_translator) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator) (2026.6.17)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: deep_translator
# Successfully installed deep_translator-1.11.4

# %%
from deep_translator import GoogleTranslator
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
SIA = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
GoogleTranslator(source='ar', target='en').translate('كيف حالك')
# Out:
# 'How are you'

# %%
def T(text) :
  return GoogleTranslator(source='ar', target='en').translate(text)

# %%
T('عامل ايه')
# Out:
# 'What are you doing?'

# %%
T('و لست بعلام الغيوب و إنما أري بلحاظ الرأي ما هو واقع')
# Out:
# 'I am not a knower of the unseen, but rather I see from the point of view what is reality'

# %%
T('في مثل هذا اليوم قامت الطائرات اليابانية بهجومٍ مباغت على قاعدة كانوهي العسكرية في شبه جزيرة موكابو، الواقعة على بعد أقل من 15 ميلًا (24 كيلومترًا) شرق ميناء بيرل هاربر في صباح 7 ديسمبر 1941، تكبدت الولايات المتحدة أكبر الخسائر العسكرية في تاريخها على الإطلاق، واضطرت لدخول الحرب العالمية الثانية.')
# Out:
# 'On this day, Japanese aircraft launched a surprise attack on the Kanohe military base on the Mokapu Peninsula, located less than 15 miles (24 kilometers) east of Pearl Harbor. On the morning of December 7, 1941, the United States suffered the largest military losses in its history ever, and was forced to enter World War II.'

# %%
T('ازيك')
# Out:
# 'How are you'

# %%
Values = list(SIA.polarity_scores('it`s a terrible restaurant').values())

print(f'Value for Negative is    :  {Values[0]}')
print(f'Value for Neutral  is    :  {Values[1]}')
print(f'Value for Positive is    :  {Values[2]}')
print(f'Value for Compound is    :  {Values[3]}')
# Out:
# Value for Negative is    :  0.608
# Value for Neutral  is    :  0.392
# Value for Positive is    :  0.0
# Value for Compound is    :  -0.4767
# dict_values([0.0, 0.408, 0.592, 0.4404])

# %%
Values = list(SIA.polarity_scores(T('فيلم زي الزفت بصراحة')).values())

print(f'Value for Negative is    :  {Values[0]}')
print(f'Value for Neutral  is    :  {Values[1]}')
print(f'Value for Positive is    :  {Values[2]}')
print(f'Value for Compound is    :  {Values[3]}')
# Out:
# Value for Negative is    :  0.0
# Value for Neutral  is    :  0.545
# Value for Positive is    :  0.455
# Value for Compound is    :  0.3612

# %%
Values = list(SIA.polarity_scores(T('مطعم رهيييب')).values())

print(f'Value for Negative is    :  {Values[0]}')
print(f'Value for Neutral  is    :  {Values[1]}')
print(f'Value for Positive is    :  {Values[2]}')
print(f'Value for Compound is    :  {Values[3]}')
# Out:
# Value for Negative is    :  0.0
# Value for Neutral  is    :  0.196
# Value for Positive is    :  0.804
# Value for Compound is    :  0.6249

# %%
print(SIA.polarity_scores("its very fantastic"))
# Out:
# {'neg': 0.0, 'neu': 0.339, 'pos': 0.661, 'compound': 0.5984}
