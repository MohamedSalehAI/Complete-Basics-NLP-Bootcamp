# %%
# !pip install fasttext
# Out:
# Collecting fasttext
#   Downloading fasttext-0.9.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 3.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pybind11>=2.2 (from fasttext)
#   Using cached pybind11-3.0.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from fasttext) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from fasttext) (2.0.2)
# Using cached pybind11-3.0.4-py3-none-any.whl (314 kB)
# Building wheels for collected packages: fasttext
#   Building wheel for fasttext (pyproject.toml) ... done
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp312-cp312-linux_x86_64.whl size=4653910 sha256=800ac609f13713da80ee5bfe40221a67183d22df008d9efee88ec322f87e4168
#   Stored in directory: /root/.cache/pip/wheels/20/27/95/a7baf1b435f1cbde017cabdf1e9688526d2b0e929255a359c6
# Successfully built fasttext
# Installing collected packages: pybind11, fasttext
# Successfully installed fasttext-0.9.3 pybind11-3.0.4

# %%
import fasttext.util

# %%
fasttext.util.download_model('en', if_exists='ignore')
# Out:
# Downloading https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.en.300.bin.gz

# %%
EnglishWE = fasttext.load_model('/content/cc.en.300.bin')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.makedirs("/content/drive/MyDrive/FastText", exist_ok=True)

# %%
# !cp /content/cc.en.300.bin /content/drive/MyDrive/FastText/
# Out:
# ^C

# %%
WE = [i for i in EnglishWE['Dog']]
len(WE)
# Out:
# 300

# %%
def EnglishWEFunction(Word) :
    WE = [i for i in EnglishWE[Word]]
    return WE

# %%
EnglishWEFunction('dog')
# Out:
# [np.float32(0.16797343),
#  np.float32(-0.0012915097),
#  np.float32(0.01619076),
#  np.float32(0.27790722),
#  np.float32(-0.10621118),
#  np.float32(0.036571708),
#  np.float32(0.2042775),
#  np.float32(0.064157106),
#  np.float32(-0.011483479),
#  np.float32(0.05821145),
#  np.float32(-0.22524177),
#  np.float32(-0.21296273),
#  np.float32(-0.07619001),
#  np.float32(-0.0495243),
#  np.float32(0.044902146),
#  np.float32(0.24309441),
#  np.float32(0.044567898),
#  np.float32(-0.028788459),
#  np.float32(-0.3035171),
#  np.float32(0.0158186),
#  np.float32(-0.20969255),
#  np.float32(-0.021452324),
#  np.float32(-0.09633946),
#  np.float32(-0.045862637),
#  np.float32(-0.02090367),
#  np.float32(-0.25138012),
#  np.float32(0.10532926),
#  np.float32(-0.1831662),
#  np.float32(0.0060016178),
#  np.float32(0.24515434),
#  np.float32(0.0032330453),
#  np.float32(0.22065218),
#  np.float32(-0.014099715),
#  np.float32(0.0683034),
#  np.float32(-0.07115323),
#  np.float32(-0.0064189658),
#  np.float32(-0.0014906079),
#  np.float32(0.069382176),
#  np.float32(-0.15117021),
#  np.float32(-0.41590753),
#  np.float32(0.08081938),
#  np.float32(0.043149598),
#  np.float32(-0.18901569),
#  np.float32(0.02689096),
#  np.float32(-0.20533894),
#  np.float32(0.028296709),
#  np.float32(0.014560129),
#  np.float32(0.038765326),
#  np.float32(-0.20197397),
#  np.float32(0.27379614),
#  np.float32(-0.2366355),
#  np.float32(-0.1277546),
#  np.float32(-0.066544175),
#  np.float32(-0.1274356),
#  np.float32(-0.24377124),
#  np.float32(0.18009841),
#  np.float32(-0.04074678),
#  np.float32(-0.015528493),
#  np.float32(-0.14595772),
#  np.float32(0.109287806),
#  np.float32(0.027287677),
#  np.float32(0.016250156),
#  np.float32(0.14619264),
#  np.float32(0.08557123),
#  np.float32(-0.1292741),
#  np.float32(-0.008422561),
#  np.float32(0.15677556),
#  np.float32(0.23729092),
#  np.float32(-0.1707532),
#  np.float32(0.12808749),
#  np.float32(-0.009494282),
#  np.float32(0.035039544),
#  np.float32(-0.07176857),
#  np.float32(-0.1995765),
#  np.float32(-0.09005836),
#  np.float32(-0.060077675),
#  np.float32(0.15112849),
#  np.float32(-0.024910847),
#  np.float32(0.036721356),
#  np.float32(0.076686725),
#  np.float32(0.017840654),
#  np.float32(-0.10687724),
#  np.float32(-0.01101496),
#  np.float32(-0.19196266),
#  np.float32(-0.022426542),
#  np.float32(-0.04039514),
#  np.float32(0.14546907),
#  np.float32(-0.023605868),
#  np.float32(0.11044045),
#  np.float32(-0.097599834),
#  np.float32(0.023792583),
#  np.float32(-0.20565659),
#  np.float32(0.01721616),
#  np.float32(0.03199153),
#  np.float32(0.008152837),
#  np.float32(0.08656359),
#  np.float32(0.18502286),
#  np.float32(0.18402475),
#  np.float32(0.10668078),
#  np.float32(0.03738188),
#  np.float32(-0.4074914),
#  np.float32(-0.040229708),
#  np.float32(0.08458148),
#  np.float32(-0.11117537),
#  np.float32(-0.25287393),
#  np.float32(0.17724703),
#  np.float32(-0.18504605),
#  np.float32(0.25140703),
#  np.float32(-0.012714244),
#  np.float32(-0.14831553),
#  np.float32(0.1600358),
#  np.float32(-0.05883258),
#  np.float32(-0.061357625),
#  np.float32(0.11166456),
#  np.float32(-0.14569472),
#  np.float32(0.14750557),
#  np.float32(-0.3153151),
#  np.float32(0.010786569),
#  np.float32(-0.15187092),
#  np.float32(-0.04359063),
#  np.float32(-0.0634594),
#  np.float32(-0.088840656),
#  np.float32(-0.057771217),
#  np.float32(-0.09834495),
#  np.float32(-0.025062118),
#  np.float32(0.07741003),
#  np.float32(-0.080654785),
#  np.float32(0.12711865),
#  np.float32(0.16980766),
#  np.float32(-0.19458896),
#  np.float32(-0.12635261),
#  np.float32(-0.05503424),
#  np.float32(-0.059657663),
#  np.float32(-0.15294074),
#  np.float32(-0.09047022),
#  np.float32(0.05964619),
#  np.float32(0.18547264),
#  np.float32(0.021849299),
#  np.float32(0.2296952),
#  np.float32(-0.13329673),
#  np.float32(-0.07195106),
#  np.float32(-0.031211872),
#  np.float32(-0.0077243745),
#  np.float32(-0.03858921),
#  np.float32(-0.06347749),
#  np.float32(0.016765416),
#  np.float32(-0.30626687),
#  np.float32(0.39329478),
#  np.float32(-0.07541074),
#  np.float32(-0.1283311),
#  np.float32(0.009501293),
#  np.float32(-0.29389495),
#  np.float32(-0.050465036),
#  np.float32(-0.12812214),
#  np.float32(-0.15552156),
#  np.float32(0.110129),
#  np.float32(0.031947453),
#  np.float32(0.02212383),
#  np.float32(-0.1495015),
#  np.float32(0.16552612),
#  np.float32(-0.17551072),
#  np.float32(0.1453113),
#  np.float32(0.1827914),
#  np.float32(-0.14981437),
#  np.float32(-0.21875371),
#  np.float32(-0.1254919),
#  np.float32(0.18674739),
#  np.float32(-0.12732399),
#  np.float32(-0.023174915),
#  np.float32(0.03523151),
#  np.float32(0.09008883),
#  np.float32(0.11684711),
#  np.float32(-0.21788248),
#  np.float32(-0.011557106),
#  np.float32(0.047200844),
#  np.float32(-0.117698625),
#  np.float32(0.15802756),
#  np.float32(0.08140251),
#  np.float32(-0.19042213),
#  np.float32(-0.13775437),
#  np.float32(0.0856982),
#  np.float32(-0.096681),
#  np.float32(-0.07519216),
#  np.float32(-0.20052913),
#  np.float32(0.10061246),
#  np.float32(0.07723006),
#  np.float32(0.2077197),
#  np.float32(-0.042454537),
#  np.float32(-0.00779141),
#  np.float32(0.15528412),
#  np.float32(-0.23522),
#  np.float32(-0.0190185),
#  np.float32(0.01032567),
#  np.float32(0.0056195483),
#  np.float32(0.103558026),
#  np.float32(0.005051328),
#  np.float32(-0.0062351897),
#  np.float32(0.15057383),
#  np.float32(-0.022162814),
#  np.float32(0.114179984),
#  np.float32(0.060052067),
#  np.float32(0.036393054),
#  np.float32(0.05854595),
#  np.float32(0.04371137),
#  np.float32(0.029149488),
#  np.float32(0.16142541),
#  np.float32(0.033821225),
#  np.float32(-0.17429261),
#  np.float32(0.08662991),
#  np.float32(0.1907782),
#  np.float32(0.07996318),
#  np.float32(-0.15227565),
#  np.float32(-0.060103737),
#  np.float32(-0.11483645),
#  np.float32(-0.104702614),
#  np.float32(-0.35195923),
#  np.float32(-0.089052565),
#  np.float32(-0.06273567),
#  np.float32(-0.014287148),
#  np.float32(-0.01347531),
#  np.float32(0.1672279),
#  np.float32(0.0007054927),
#  np.float32(0.07096557),
#  np.float32(-0.044050395),
#  np.float32(0.13617563),
#  np.float32(0.037749834),
#  np.float32(0.16895525),
#  np.float32(-0.04593222),
#  np.float32(-0.10215944),
#  np.float32(0.034580186),
#  np.float32(-0.19589837),
#  np.float32(0.045083378),
#  np.float32(-0.07737713),
#  np.float32(0.13069247),
#  np.float32(-0.014187038),
#  np.float32(-0.025347799),
#  np.float32(-0.193466),
#  np.float32(0.033326354),
#  np.float32(-0.044809647),
#  np.float32(0.153066),
#  np.float32(-0.008619595),
#  np.float32(-0.07667975),
#  np.float32(-0.20965469),
#  np.float32(-0.18245429),
#  np.float32(0.1157611),
#  np.float32(-0.17064586),
#  np.float32(0.06850301),
#  np.float32(-0.0045300736),
#  np.float32(0.0069396384),
#  np.float32(0.038153842),
#  np.float32(0.031017354),
#  np.float32(-0.0461829),
#  np.float32(0.0432574),
#  np.float32(-0.1529224),
#  np.float32(-0.40706924),
#  np.float32(0.101857364),
#  np.float32(-0.04173297),
#  np.float32(-0.12702906),
#  np.float32(0.034665015),
#  np.float32(0.101607725),
#  np.float32(-0.040658325),
#  np.float32(-0.11958931),
#  np.float32(-0.0040996224),
#  np.float32(-0.0848252),
#  np.float32(-0.14605616),
#  np.float32(0.032799657),
#  np.float32(-0.1637969),
#  np.float32(0.026055489),
#  np.float32(-0.019874472),
#  np.float32(-0.10404594),
#  np.float32(0.021198114),
#  np.float32(0.14655825),
#  np.float32(-0.17055693),
#  np.float32(0.0447331),
#  np.float32(-0.25232658),
#  np.float32(0.04228683),
#  np.float32(-0.06107245),
#  np.float32(0.11194584),
#  np.float32(-0.078010306),
#  np.float32(-0.11292272),
#  np.float32(0.0557847),
#  np.float32(0.045020815),
#  np.float32(-0.1698344),
#  np.float32(-0.025950298),
#  np.float32(-0.06438185),
#  np.float32(0.1335313),
#  np.float32(-0.12403029),
#  np.float32(-0.08875973),
#  np.float32(-0.055613212),
#  np.float32(-0.17166188),
#  np.float32(-0.092145644),
#  np.float32(-0.039017946),
#  np.float32(-0.141013),
#  np.float32(0.074793234),
#  np.float32(0.22649087),
#  np.float32(-0.20450641),
#  np.float32(-0.15849999),
#  np.float32(0.30272514),
#  np.float32(0.0942003),
#  np.float32(0.1539942)]

# %%
EnglishWE.get_words()[:20]
# Out:
# [',',
#  'the',
#  '.',
#  'and',
#  'to',
#  'of',
#  'a',
#  '</s>',
#  'in',
#  'is',
#  ':',
#  'I',
#  'for',
#  'that',
#  ')',
#  '"',
#  '(',
#  'on',
#  'with',
#  'it']

# %%
len(EnglishWE.get_words())
# Out:
# 2000000

# %%
def SimilarWords(Word) :
    Word = Word.lower()
    if Word in EnglishWE.get_words() :
        WordsDifference = {}
        for EachWord in EnglishWE.get_words()[:10000] :
            WordsDifference[EachWord] = sum([abs(float(i)-float(j)) for i,j in zip([i for i in EnglishWE[Word]],[i for i in EnglishWE[EachWord]])])
        return list({k: v for k, v in sorted(WordsDifference.items(), key=lambda item: item[1])}.items())[:10]
    else :
        return 'Word not exists'

# %%
# WordsDifference = {'book':15.6, 'university':19.3 . . . . . . .}

# %%
SimilarWords('good')
# Out:
# [('good', 0.0),
#  ('great', 9.928391179710161),
#  ('decent', 10.087051496874665),
#  ('excellent', 11.231233969156165),
#  ('better', 11.446643645584118),
#  ('pretty', 11.571182941319421),
#  ('terrific', 11.663844823160616),
#  ('really', 11.697962307807757),
#  ('nice', 11.842659651156282),
#  ('terrible', 11.926131740139681)]

# %%
SimilarWords('awful')
# Out:
# [('awful', 0.0),
#  ('horrible', 7.350138985166268),
#  ('terrible', 7.6622938341024565),
#  ('ridiculous', 10.561988652829314),
#  ('unfortunate', 11.184722229219915),
#  ('stupid', 11.248670937231509),
#  ('frustrating', 11.301680536700587),
#  ('pretty', 11.343915693869349),
#  ('annoying', 11.383076160767814),
#  ('awesome', 11.460798780335608)]

# %%
SimilarWords('Egypt')
# Out:
# [('Egypt', 14.153405567631125),
#  ('Egyptian', 15.583376786729787),
#  ('ancient', 17.398544892581413),
#  ('Afghanistan', 17.502620629653393),
#  ('Palestine', 17.57370877219364),
#  ('Pakistan', 17.58004485946003),
#  ('university', 17.845438563570497),
#  ('Mediterranean', 17.888189511024393),
#  ('revolution', 17.925125759659295),
#  ('Bangladesh', 17.934947718833826)]
