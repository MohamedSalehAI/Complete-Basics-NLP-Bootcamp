# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.13.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.26.8)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)

# %%
from transformers import AutoTokenizer, AutoModelForMaskedLM

tokenizer = AutoTokenizer.from_pretrained("albert-base-v2")

model = AutoModelForMaskedLM.from_pretrained("albert-base-v2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/684 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/760k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.31M [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 47.4MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/29 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie predictions.bias to predictions.decoder.bias, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# [transformers] AlbertForMaskedLM LOAD REPORT from: albert-base-v2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# albert.pooler.bias   | UNEXPECTED |  |
# albert.pooler.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
tokenizer("  play football       ")
# Out:
# {'input_ids': [2, 418, 435, 3], 'attention_mask': [1, 1, 1, 1]}

# %%
from transformers import pipeline
unmasker = pipeline('fill-mask', model='albert-base-v2')
results = unmasker("The man worked as a [MASK].")
results
# Out:
# Loading weights:   0%|          | 0/29 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie predictions.bias to predictions.decoder.bias, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# [transformers] AlbertForMaskedLM LOAD REPORT from: albert-base-v2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# albert.pooler.bias   | UNEXPECTED |  |
# albert.pooler.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [{'score': 0.02957766503095627,
#   'token': 28744,
#   'token_str': 'chauffeur',
#   'sequence': 'the man worked as a chauffeur .'},
#  {'score': 0.028866471722722054,
#   'token': 29477,
#   'token_str': 'janitor',
#   'sequence': 'the man worked as a janitor .'},
#  {'score': 0.025811953470110893,
#   'token': 29024,
#   'token_str': 'shoemaker',
#   'sequence': 'the man worked as a shoemaker .'},
#  {'score': 0.018498025834560394,
#   'token': 21238,
#   'token_str': 'blacksmith',
#   'sequence': 'the man worked as a blacksmith .'},
#  {'score': 0.0182074885815382,
#   'token': 3672,
#   'token_str': 'lawyer',
#   'sequence': 'the man worked as a lawyer .'}]

# %%
for r in results :
  print(f'result : ({r["sequence"]})  with score : ({r["score"]}) ')
# Out:
# result : (the man worked as a chauffeur .)  with score : (0.02957766503095627)
# result : (the man worked as a janitor .)  with score : (0.028866471722722054)
# result : (the man worked as a shoemaker .)  with score : (0.025811953470110893)
# result : (the man worked as a blacksmith .)  with score : (0.018498025834560394)
# result : (the man worked as a lawyer .)  with score : (0.0182074885815382)

# %%
def CompletePhrase(text) :
  unmasker = pipeline('fill-mask', model='albert-base-v2')
  results = unmasker(text)
  for r in results :
    print(f'result : ({r["sequence"]})  with score : ({r["score"]}) ')

# %%
CompletePhrase('[MASK] is the capital of Greece')
# Out:
# Loading weights:   0%|          | 0/29 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie predictions.bias to predictions.decoder.bias, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# [transformers] AlbertForMaskedLM LOAD REPORT from: albert-base-v2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# albert.pooler.bias   | UNEXPECTED |  |
# albert.pooler.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# result : (thessaloniki is the capital of greece)  with score : (0.35404691100120544)
# result : (athens is the capital of greece)  with score : (0.08959899097681046)
# result : (greece is the capital of greece)  with score : (0.06178496032953262)
# result : (crete is the capital of greece)  with score : (0.0370519757270813)
# result : (constantinople is the capital of greece)  with score : (0.023933643475174904)

# %%
CompletePhrase('I called [MASK] today')
# Out:
# Loading weights:   0%|          | 0/29 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie predictions.bias to predictions.decoder.bias, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# [transformers] AlbertForMaskedLM LOAD REPORT from: albert-base-v2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# albert.pooler.bias   | UNEXPECTED |  |
# albert.pooler.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# result : (i called evalle today)  with score : (0.3506721556186676)
# result : (i called joyah today)  with score : (0.05085768550634384)
# result : (i called 911 today)  with score : (0.018181348219513893)
# result : (i called yesterday today)  with score : (0.010992569848895073)
# result : (i called my today)  with score : (0.007235193625092506)

# %%
unmasker = pipeline('fill-mask', model='xlm-roberta-base')
unmasker("Hello I'm a <mask> model.")
# Out:
# Downloading:   0%|          | 0.00/1.04G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/4.83M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/8.68M [00:00<?, ?B/s]
# [{'score': 0.10563939809799194,
#   'sequence': "Hello I'm a fashion model.",
#   'token': 54543,
#   'token_str': 'fashion'},
#  {'score': 0.08015312254428864,
#   'sequence': "Hello I'm a new model.",
#   'token': 3525,
#   'token_str': 'new'},
#  {'score': 0.03341330587863922,
#   'sequence': "Hello I'm a model model.",
#   'token': 3299,
#   'token_str': 'model'},
#  {'score': 0.030217627063393593,
#   'sequence': "Hello I'm a French model.",
#   'token': 92265,
#   'token_str': 'French'},
#  {'score': 0.02643582969903946,
#   'sequence': "Hello I'm a sexy model.",
#   'token': 17473,
#   'token_str': 'sexy'}]

# %%
def CompletePhrase(text) :
  unmasker = pipeline('fill-mask', model='xlm-roberta-base')
  results = unmasker(text)
  for r in results :
    print(f'result : ({r["sequence"]})  with score : ({r["score"]}) ')

# %%
CompletePhrase('<mask> is the capital of Greece')
# Out:
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 1.12GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# [transformers] XLMRobertaForMaskedLM LOAD REPORT from: xlm-roberta-base
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.bias   | UNEXPECTED |  |
# roberta.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# result : (Sofia is the capital of Greece)  with score : (0.23936505615711212)
# result : (Athen is the capital of Greece)  with score : (0.12998077273368835)
# result : (It is the capital of Greece)  with score : (0.0917128175497055)
# result : (Vilnius is the capital of Greece)  with score : (0.07483269274234772)
# result : (This is the capital of Greece)  with score : (0.07441593706607819)

# %%
CompletePhrase('I called <mask> today')
# Out:
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# [transformers] XLMRobertaForMaskedLM LOAD REPORT from: xlm-roberta-base
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.bias   | UNEXPECTED |  |
# roberta.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# result : (I called her today)  with score : (0.4408698081970215)
# result : (I called you today)  with score : (0.18305560946464539)
# result : (I called it today)  with score : (0.03988809138536453)
# result : (I called him today)  with score : (0.02678818069398403)
# result : (I called them today)  with score : (0.022263826802372932)
