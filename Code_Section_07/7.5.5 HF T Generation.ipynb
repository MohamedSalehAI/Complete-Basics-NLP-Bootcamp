# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (5.13.1)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (1.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers) (0.26.8)
# Requirement already satisfied: safetensors>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from transformers) (4.67.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers) (0.0.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:138: UserWarning:
# Error while fetching `HF_TOKEN` secret value from your vault: 'Requesting secret HF_TOKEN timed out. Secrets can only be fetched when running from the Colab UI.'.
#   warnings.warn(f"\nError while fetching `HF_TOKEN` secret value from your vault: '{str(e)}'.")
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  548MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# [transformers] Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer GPT2Tokenizer. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# [{'generated_text': "Hello, I'm a language model, so I can write things that are easy to understand with a little bit of code. But when you think of words, it's hard to think of words that are as simple as a little word in a sentence.\n\nSo I'm going to use a little bit of code, and I'll talk a little bit about the syntax.\n\nThis is how you write your first line:\n\n$trans = new $trans [1, 2, 3, 4]; $trans -> write ( 'Hello, I'm a language model, so I can write things that are easier to understand with a little bit of code.' );\n\nThis code is pretty simple, but it really doesn't have to be. We want to write this code in a few lines, and we're going to use an expression, which is a shorthand for the literal of the language.\n\nIn this case, we're going to use a variable named trans that's a symbol. We want to write this expression as an expression, where we're going to look for a line that matches the line we want to write.\n\nThe syntax for writing a line like this is very simple:\n\n$trans = new $trans [1, 2, 3, 4]; $"},
#  {'generated_text': "Hello, I'm a language model, I've had a lot of good experiences with it, I'm a native speaker. I've been working with it for almost five years.\n\nWe're working on different programming languages. I'm working on several different languages.\n\nDo I feel like I'm in a better position to work on this type of thing?\n\nNo. I don't feel like I'm in a better position to work on this type of thing. I feel like I'm in a better position to work on code that's actually good.\n\nIt's not like I'm the only person that's been able to master a language. Even if you're not a very good programmer, I'd be more inclined to be able to master that language. That's what I'm working on.\n\nDo you have any thoughts on the idea of using some of the other languages that are now out there, especially Clojure, Python, and even the Java language?\n\nNo, I don't think Clojure is a better language. It's just a better language. I don't think I've ever been able to understand it before. Clojure is a very well-developed language.\n\nI think it's fun to be able to work on other languages, and I think it"},
#  {'generated_text': 'Hello, I\'m a language model, I\'m an editor," the writer said. "But I don\'t think that\'s a good idea. I mean, what are you doing?"\n\nA few words from the man, who did not return calls.\n\nHe said she was "overworked" and that he had "made a mistake." "I think there\'s not one right answer," he said, adding that he had been told there were "no more questions."\n\nThe writer said the problem stemmed from her job as a writer in the online publication The New Yorker, where she was a part-time writer and editor.\n\nShe said she had been told that while she was happy to work at The New Yorker, her "job at this time was to write fiction and I was not. I thought I could have a full-time job at The New Yorker. I was wrong."\n\nThe writer\'s employer did not respond to a request for comment Friday.\n\nThe writer was a co-founder of G.I. Joe\'s magazine and a co-founder of the online publishing company Ado, which has its own website.\n\nA copy of G.I. Joe\'s website listed her as "a contributing editor and contributing editor to [The New Yorker]."'},
#  {'generated_text': 'Hello, I\'m a language model, and it\'s not about me. It\'s about people.\n\n"If you\'re a person and you want to tell people what a language is, you have to be able to tell them what the language is about."\n\nLang, who came to the UK with her mother, has been studying English since she was 8.\n\nShe says she is passionate about how to understand people and how they use language.\n\n"I\'m a language model, and it\'s not about me. It\'s about people. It\'s about people as far as I\'m concerned."\n\nShe says she\'s always been interested in learning English and how to express herself and the world around her.\n\nBut she also says she doesn\'t understand why some people don\'t understand her and her language.\n\n"What do you get when you talk about the world of your language?"\n\n"You get to know people and you know people speak more than you do, but you\'re not allowed to do that.\n\n"So you\'re not allowed to do that."\n\nTheresa May has repeatedly claimed she wants to "unite the world" and is working to create an "open-ended" international language system.\n\nBut the Government has'},
#  {'generated_text': 'Hello, I\'m a language model, not a language model. I\'m thinking of the languages in which we have formal semantics. One of my favorite languages is C#, which is the language of the language model. We\'re not talking about the semantics of a language model in a formal sense. We\'re talking about language models in which the language model is the only set of semantics that you can apply to any particular language.\n\nOne of the things I like about this kind of formal semantics is that it\'s a good way to develop a language model without having to go through languages that are not formal models. And I think you can do it with C#, which is not formal models.\n\nA lot of the things you will be interested in coming out of this are examples of non-formal semantics. I would like to talk about the second way that you can say, "I want to write this language model in C#."\n\nThere\'s a lot of things that you will be interested in. First of all, we have the language model. It\'s a language model, it\'s not a syntax model. We have a language model that we can do what we want. It\'s a language model that we can look at. It\'s a language model that you can apply to'}]

# %%
generator("can I ask you a question", max_length=30, num_return_sequences=5)
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'can I ask you a question?"\n\nI looked at the man in the mirror. "You\'re right."\n\nI looked at him in the mirror. "Of course."\n\nHe looked at me. "You see that, right?"\n\nIn a moment I heard a soft thump. I was staring into the mirror, back at him.\n\n"Yes," he said. "I\'m not sure if you\'re going to say anything right now. Are you sure? Do you want to talk tomorrow?"\n\nI did.\n\n"I\'m not sure what I\'m going to say," he said. "I don\'t think I want to talk about this, but I\'ll tell you."\n\nI said nothing.\n\n"I don\'t think I\'ll tell you," he said. "But I do know that I do want to, and I do know that I\'d be happy to. I think I\'d like to. I think I\'d like to talk to you about something you really care about."\n\nI did.\n\nHe stared at me. "I\'m not sure. I just think it would be best if I could. That would be good. I don\'t think it would be good. I\'m not sure if'},
#  {'generated_text': 'can I ask you a question?\n\nDANNY: No.\n\nDANNY: You know, I think it\'s probably fair to ask you a question about the way the system works. I think it\'s really about how we make sure that we allow people to have a fair vote. I think that when people see it, they think, \'Oh, yeah, this guy is going to get elected,\' and then they think, \'Well, I\'m going to make a little money, and if I don\'t make a little money, I\'m going to be a great president,\' and then they kind of just assume that that\'s what, and then they kind of think, \'Well, well, I don\'t know what to make of that.\'"'},
#  {'generated_text': "can I ask you a question you will probably have no idea about:\n\n1. It's not my fault – it's not my fault that I got a call from another guy. Just because a guy wants to talk to me doesn't mean I should say no.\n\n2. It's not my fault – I don't have a girlfriend. Don't think about that. I have a girlfriend. I love her. I don't have to tell you what to think. I just need to know.\n\n3. It's not my fault – I didn't want to be. I'm just not ready for it.\n\n4. It's not my fault – I don't know what to do about it. My body is fine. It's just not ready for me.\n\n5. It's not my fault – I'd rather be alone. I'd rather be alone than have to deal with other people.\n\n6. It's not my fault – it's just not my fault.\n\n7. It's not my fault – I'd rather be alone. I'd rather be alone than have to deal with other people.\n\n8. It's not my fault – I'd rather be alone. I'd rather be alone than have to deal"},
#  {'generated_text': 'can I ask you a question about this?"\n\n"I don\'t want to answer that," he answered. "I don\'t have an answer."\n\n"I am not a doctor," Harry said. "I am only a witch."\n\n"You are a witch?"\n\n"No," Harry said. "I am not a witch. I mean, I am a witch. What does that mean?"\n\n"I can\'t answer this question," Harry replied.\n\n"You don\'t want to answer it?"\n\n"No. I don\'t want to answer it."\n\n"You don\'t understand?"\n\n"I don\'t understand," Harry said. "I don\'t understand. I don\'t understand. I understand. So why not?"\n\n"I don\'t know," Harry said. "I don\'t understand."\n\n"What does it mean?"\n\n"I don\'t know," Harry said. "I don\'t understand."\n\n"So what do you mean?"\n\n"I can\'t answer this question," Harry said.\n\n"I don\'t understand," Harry said. "I don\'t understand."\n\n"So what do you mean?"\n\n"I can\'t answer this question," Harry said'},
#  {'generated_text': "can I ask you a question: where do you think the current crop of young, white, middle-class Americans are going to be when the economy is good again?\n\nThat's the question I want to ask you.\n\nI think the answer is, in a way, that the economic situation has gotten better. The economy didn't get better, and it's gotten worse.\n\nI think the economy has gotten even better economically. So I think what makes this country great is that the American people are getting better. And if you look at what we're doing in the United States right now, we're doing things that are not going to get better.\n\nAnd so we know that with the help of our new president, we're going to have more people coming to work, more people coming into this country, and our economy is going to continue to grow. And we're going to have more people coming to work, more people coming into this country, and we're going to have more people coming in and working.\n\nAnd we're going to have more people coming in and working. And we're going to have more people coming in and working. And I think the people that are coming in, they're going to have more opportunities to do something better.\n"}]

# %%
generator("Albert Einstein is one of the most", max_length=30, num_return_sequences=5)
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Albert Einstein is one of the most famous physicists ever to be able to prove the existence of the Universe. He was one of the first to use the theory of relativity to predict the existence of the Universe. Einstein was one of the most famous physicists ever to be able to prove the existence of the Universe. He was one of the first to use the theory of relativity to predict the existence of the Universe.\n\nThe Bible has many references for many of the topics of this book. For example, many of the Bible references are listed on the right side of the page.\n\nMany of these verses have nothing to do with Einstein but are actually from the Bible.\n\nThe Bible is used in many of these places, including:\n\n- The Bible is used in many places, including:\n\n- The Bible is used in many places, including:\n\n- The Bible is used in many places, including:\n\n- The Bible is used in many places, including:\n\n- The Bible is used in many places, including:\n\n- The Bible is used in many places, including:\n\n- The Bible is used in many places, including:\n\n- The Bible is used in many places, including:\n\n- The Bible is used in many places,'},
#  {'generated_text': "Albert Einstein is one of the most famous philosophers of the 20th century. He was born in Paris in 1871. He took the name of the philosopher of the 20th century as a reference to Einstein's theoretical works. He was also a major proponent of the idea of absolute freedom (Tawkentianism). In 1877, he published a book entitled The Absolute State: A Philosophical Treatise on the Nature of the Absolute (Thierry K. Klimontin and Lorne A. A. Berescoe). He wrote a book of short essays entitled The Absolute State in 1878, in which he discusses the situation of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state of the state"},
#  {'generated_text': 'Albert Einstein is one of the most famous physicists of the 20th century. He wrote about the first quantum theory of relativity, which he called the "God particle theory" and was quoted as saying about Einstein\'s theory in the 1930s: "His theory was not a particle theory, but an extension of it and the theory had the effect of getting the matter to move through space, and it did."\n\nHe was also quoted as saying that Einstein had been a "good man" in the early 1900s, when the Austrian physicist Carl von Clausewitz called him "the most brilliant man of the 20th century."\n\nThe great physicist died in the late 1950s of a heart attack and was buried in a cemetery in Munich, Germany.\n\nThe Associated Press contributed to this report.'},
#  {'generated_text': 'Albert Einstein is one of the most famous physicists of all time. His work on quantum mechanics was published in 1931. Einstein\'s name was first mentioned in the 18th century by Newton and his theory of relativity is known as the "new general theory of relativity". The fact that the first theory has now been applied to the universe and physics has led to the development of the modern era of quantum mechanics.\n\nIn The Physics of the Universe\n\nEinstein\'s work on the physics of the universe was translated into English by the late Professor James Watson in the late 1950s. The British scholar had been working on the theory of relativity for over ten years before he received an invitation to write an article for the American Journal of Physics. Watson had a book entitled "The Physics of the Universe" published in 1954. Einstein\'s work was later translated into English as "The Physics of the Universe", which translated into English as "The Physics of the Universe" and it was translated into French by the French philosopher Jean-Paul Sartre in 1969.\n\nEinstein\'s book was translated into English as "The Physics of the Universe" in 1974. The translation was done in the early 1980s by the French philosopher Voltaire, who also translated the book into English. In 1993, the English translation of Einstein'},
#  {'generated_text': "Albert Einstein is one of the most famous physicists of the world. He was born in 1836 in the German city of Graz. In 1848, Einstein was appointed as the first post-doctoral fellow at the Institute of Physics in Vienna. With the help of the Austrian physicist and mathematician Friedrich Nösschen of the Vienna University, he and Nösschen developed the first atomic theory, which was published in 1865, the year Einstein was born. Einstein's theory of relativity was published in 1867, the year he was born.\n\nHe was the first to introduce quantum mechanics to physics in order to prove that the first wave of elementary particles, the electromagnetic waves, existed. After the first wave of elementary particles had been discovered, they were thought to be the most fundamental particles of the universe. They could not exist in a vacuum. Einstein believed that if all particles existed in a single place, then they could not be affected by the influence of a single particle, or any other force.\n\nHe established that the electromagnetic waves, which are fundamental elements in the fabric of the universe, are at least as fundamental as the light, and were therefore extremely powerful. He concluded that light could not be produced by the electromagnetic waves. He concluded that light was the only light ever produced by the universe"}]
